# %%
import numpy as np
import seaborn as sns
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
import itertools
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import tree
from keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.neighbors import KNeighborsRegressor
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping
from keras.models import load_model
from numpy.random import seed
from statsmodels.stats.multitest import multipletests
from scipy.stats import ranksums
from more_itertools import powerset
from numpy import cov

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'    

pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

sns.set()
warnings.filterwarnings('ignore')
random_seed = 10000
seed(random_seed)

# %%
df = pd.read_csv('winequality.csv')
y_label = 'quality'
df = df._get_numeric_data()
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0  7.4            0.70              0.00         1.9             0.076      11.0                 34.0                  0.9978   3.51  0.56       9.4      5
# 1  7.8            0.88              0.00         2.6             0.098      25.0                 67.0                  0.9968   3.20  0.68       9.8      5
# 2  7.8            0.76              0.04         2.3             0.092      15.0                 54.0                  0.9970   3.26  0.65       9.8      5
# 3  11.2           0.28              0.56         1.9             0.075      17.0                 60.0                  0.9980   3.16  0.58       9.8      6
# 4  7.4            0.70              0.00         1.9             0.076      11.0                 34.0                  0.9978   3.51  0.56       9.4      5
# 5  7.4            0.66              0.00         1.8             0.075      13.0                 40.0                  0.9978   3.51  0.56       9.4      5
# 6  7.9            0.60              0.06         1.6             0.069      15.0                 59.0                  0.9964   3.30  0.46       9.4      5
# 7  7.3            0.65              0.00         1.2             0.065      15.0                 21.0                  0.9946   3.39  0.47       10.0     7
# 8  7.8            0.58              0.02         2.0             0.073      9.0                  18.0                  0.9968   3.36  0.57       9.5      7
# 9  7.5            0.50              0.36         6.1             0.071      17.0                 102.0                 0.9978   3.35  0.80       10.5     5

# %% [markdown]
# ## Correlation to Sale-Price

# %%
correlation = df.corr()[y_label].sort_values()
dd = pd.DataFrame(correlation)
chart = sns.barplot(correlation.index, correlation.values, palette="Blues_d")

_ = chart.set_xticklabels(chart.get_xticklabels(), rotation=90)

# %%
features = abs(df.corr())[y_label].sort_values(ascending=False)
top_8_cats = [features[i] for i in (0,1,2,3,-1,-2,-3,-4)]
for i, cat in enumerate(top_8_cats.index):
    print(str(i + 1) + ") " + cat)
data = df[list(top_8_cats.index) + [y_label]]
# Out:
# 1) free sulfur dioxide
# 2) pH
# 3) fixed acidity
# 4) chlorides
# 5) density
# 6) total sulfur dioxide
# 7) citric acid
# 8) sulphates

# %% [markdown]
# ## Visualization

# %%
_ = sns.pairplot(data=data, y_vars=[y_label], x_vars=data.columns, kind="reg", diag_kind="kde", plot_kws={'line_kws':{'color':'purple'}, 'scatter_kws': {'alpha': 0.2}})

# %% [markdown]
# # Correlation Heatmap

# %%
_ = sns.heatmap(data.corr(), cmap="BrBG", linewidths = 1, vmin = -1, vmax = 1, annot = True)

# %%
corr = data.corr().values

# %% [markdown]
# # Neural Network Training

# %%
test_precent = 0.2
train_precent = 1.0 - test_precent
train_data = data.sample(frac=train_precent, random_state=random_seed)
test_data = data.drop(train_data.index)

# %%
train_stats = train_data.describe().T
def normalize(x):
    result = x.copy()
    for feature_name in x.columns:
        average = x[feature_name].mean()
        std = x[feature_name].std()
        result[feature_name] = (x[feature_name] - average) / std
    return result
normalized_train_data = normalize(train_data)
normalized_test_data = normalize(test_data)
normalized_train_data.head()
# Out:
#       free sulfur dioxide        pH  fixed acidity  chlorides   density  total sulfur dioxide  citric acid  sulphates   quality
# 1222  1.581645            -0.331758 -0.123044      -0.205047   0.025000  1.264177             -0.258383    -1.155690   0.458744
# 770   0.740085             1.552081 -0.705262      -0.115118   0.373818  1.413905             -1.300551    -0.745066   0.458744
# 1286  0.085538             0.252882 -0.705262      -0.429869  -1.824794 -0.472668              0.888002    -0.686406   0.458744
# 886  -0.756022             0.122962  0.400952      -0.092636   0.860050 -0.562504             -0.779467    -0.041140   0.458744
# 530  -1.410569             0.642641  0.459173      -0.205047   1.198298 -0.562504             -0.154166     1.249391   0.458744

# %%
_ = plt.hist(normalized_train_data[y_label], bins = 30)

# %%
train_x = normalized_train_data.drop(y_label, axis = 1)
train_y = normalized_train_data[y_label]
test_x = normalized_test_data.drop(y_label, axis = 1)
test_y = normalized_test_data[y_label]

# %%
def build_fully_NN_model(train):
    input_layer    = Input(shape=(train.shape[1],))
    hidden_layer_1 = Dense(10, activation=tf.nn.relu)(input_layer)
    hidden_layer_2 = Dense(10, activation=tf.nn.relu)(hidden_layer_1)
    output_layer   = Dense(1)(hidden_layer_2)
   
    model = Model(input=[input_layer], output=[output_layer])
    
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    
    return model

# %%
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

def train_model(model, X, Y, show_dots = True):
    mc = ModelCheckpoint('best_nn_model.nn', monitor='val_loss', mode='min', verbose=0, save_best_only=True)
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=50)
    callbacks=[mc, es]
    if show_dots:
        callbacks.append(PrintDot())
    history = model.fit(X, Y, epochs=200, validation_split = 0.33, verbose=0, callbacks=callbacks)
    model = load_model('best_nn_model.nn')
    return history, model

# %%
runs_amount = 5
runs = dict()
all_features_label = 'all features'
runs[all_features_label] = []
for i in range(runs_amount):
    fully_NN_model = build_fully_NN_model(train_x)
    fully_NN_history, fully_NN_model = train_model(fully_NN_model, train_x, train_y, False)
    loss, mse = fully_NN_model.evaluate(test_x, test_y, verbose=0)
    runs[all_features_label].append(mse)
    print('.', end='')
    
runs[all_features_label].append(0.0)
runs[all_features_label].append(0.0)
runs[all_features_label].append(0.0)
runs[all_features_label].append(0.0)
# Out:
# .....

# %%
def build_halved_model(group1, group2, group3, group4):
    input1 = Input(shape=(len(group1),))
    hidden1_1 = Dense(4, activation='relu')(input1)
    hidden1_2 = Dense(4, activation='relu')(hidden1_1)
    out1 = Dense(1)(hidden1_2)
    
    input2 = Input(shape=(len(group2),))
    hidden2_1 = Dense(4, activation='relu')(input2)
    hidden2_2 = Dense(4, activation='relu')(hidden2_1)
    out2 = Dense(1)(hidden2_2)
    
    input3 = Input(shape=(len(group3),))
    hidden3_1 = Dense(4, activation='relu')(input3)
    hidden3_2 = Dense(4, activation='relu')(hidden3_1)
    out3 = Dense(1)(hidden3_2)
    
    input4 = Input(shape=(len(group4),))
    hidden4_1 = Dense(4, activation='relu')(input4)
    hidden4_2 = Dense(4, activation='relu')(hidden4_1)
    out4 = Dense(1)(hidden4_2)
    
    merge = concatenate([out1, out2, out3, out4], name='merge')
    #hidden = Dense(4, activation='relu')(merge)
    #hidden_x = Dense(4)(hidden)
    output = Dense(1)(merge)
    
    model = Model(inputs=[input1, input2, input3, input4], outputs=output)
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    
    return model
def calc_halved_NN_mse(g1, g2, g3, g4):
    halved_train_X = [train_x[g1], train_x[g2], train_x[g3], train_x[g4]]
    halved_train_Y = train_y
    halved_test_X = [test_x[g1], test_x[g2], test_x[g3], test_x[g4]]
    halved_test_Y = test_y
    name = (str(g1), str(g2), str(g3), str(g4))
    runs[name] = []
    for i in range(runs_amount):
        halved_model = build_halved_model(g1, g2, g3, g4)
        _, halved_model = train_model(halved_model, halved_train_X, halved_train_Y, False)
        _, mse = halved_model.evaluate(halved_test_X, halved_test_Y, verbose=0)
        runs[name].append(mse)
    return name

# %%
iteration = 0

def is_lower(g1, g2):
    val1 = g1[0] * 8 + g1[1]
    val2 = g2[0] * 8 + g2[1]
    return val1 < val2

def is_unique(g1, g2, g3, g4):
    vals = g1 + g2 + g3 + g4
    return len(vals) == len(set(vals))

def all_2_2_2_2():
    all_combinations = list(itertools.combinations(list(range(8)), 2))
    combinations = []
    all_options = []
    for g1 in all_combinations:
        for g2 in all_combinations:
            if is_lower(g1, g2):
                for g3 in all_combinations:
                    if is_lower(g2, g3):
                        for g4 in all_combinations:
                            if is_lower(g3, g4):
                                if is_unique(g1, g2, g3, g4):
                                    combinations.append((g1, g2, g3, g4))
    return combinations

def get_corr(subset):
    return corr[subset[0], subset[1]]
for subset1, subset2, subset3, subset4 in all_2_2_2_2():
    g1 = [top_8_cats.index[i] for i in subset1]
    g2 = [top_8_cats.index[i] for i in subset2]
    g3 = [top_8_cats.index[i] for i in subset3]
    g4 = [top_8_cats.index[i] for i in subset4]
    
    #for __ in range(runs_amount):
    name = calc_halved_NN_mse(g1, g2, g3, g4)

    runs[name].append(get_corr(subset1))
    runs[name].append(get_corr(subset2))
    runs[name].append(get_corr(subset3))
    runs[name].append(get_corr(subset4))
    print('.', end= '')
    iteration += 1
    pd.DataFrame(runs).transpose().to_csv('NN_test_set_prediction_results' + str(iteration) + '.csv')

#scores = [calc_halved_NN_mse(group1, group2) for (group1, group2) in groups]
#merged_parametric_rank_sum['Halved_NN_MSE'] = scores
# Out:
# .........................................................................................................

# %%
pd.DataFrame(runs).transpose().to_csv('NN_test_set_prediction_results.csv')

# %%
runs
# Out:
# {'all features': [0.6290302872657776,
#   0.6539837121963501,
#   0.5986043810844421,
#   0.6578795909881592,
#   0.62245774269104,
#   0.0,
#   0.0,
#   0.0,
#   0.0],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.6816796064376831,
#   0.6714694499969482,
#   0.649453341960907,
#   0.6189787983894348,
#   0.6541429758071899,
#   0.07037749850494217,
#   0.093705186321305,
#   0.07126947620310328,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6326217651367188,
#   0.60652095079422,
#   0.6320041418075562,
#   0.6141029596328735,
#   0.6190463304519653,
#   0.07037749850494217,
#   0.093705186321305,
#   0.364947175211252,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6390162706375122,
#   0.6604848504066467,
#   0.6312339305877686,
#   0.6281868815422058,
#   0.638940155506134,
#   0.07037749850494217,
#   0.093705186321305,
#   0.14850641172078524,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.6406501531600952,
#   0.6301472187042236,
#   0.641504168510437,
#   0.6838375329971313,
#   0.6502496004104614,
#   0.07037749850494217,
#   0.6680472921189711,
#   0.04740046825907533,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6156340837478638,
#   0.6125046610832214,
#   0.6323313117027283,
#   0.5951176881790161,
#   0.6073106527328491,
#   0.07037749850494217,
#   0.6680472921189711,
#   0.2038229138290425,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6519438624382019,
#   0.6416398286819458,
#   0.6157928705215454,
#   0.6581869125366211,
#   0.6413317918777466,
#   0.07037749850494217,
#   0.6680472921189711,
#   0.371260481285427,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'density']",
#   "['citric acid', 'sulphates']"): [0.6376835107803345,
#   0.6473631858825684,
#   0.6635873913764954,
#   0.6478387117385864,
#   0.6377391815185547,
#   0.07037749850494217,
#   -0.11318144304548039,
#   0.200632326641512,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'citric acid']",
#   "['density', 'sulphates']"): [0.6637935042381287,
#   0.6423824429512024,
#   0.6600121855735779,
#   0.6344426870346069,
#   0.6733853220939636,
#   0.07037749850494217,
#   -0.11318144304548039,
#   0.2038229138290425,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'sulphates']",
#   "['density', 'citric acid']"): [0.6323081851005554,
#   0.6472058892250061,
#   0.6724478006362915,
#   0.6508182883262634,
#   0.6470085382461548,
#   0.07037749850494217,
#   -0.11318144304548039,
#   0.371260481285427,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'density']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6294115781784058,
#   0.6436120271682739,
#   0.6139754056930542,
#   0.6338579654693604,
#   0.6497040390968323,
#   0.07037749850494217,
#   0.6717034347641041,
#   0.200632326641512,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['density', 'sulphates']"): [0.6792430877685547,
#   0.6664866805076599,
#   0.6606870293617249,
#   0.6747487187385559,
#   0.6458545327186584,
#   0.07037749850494217,
#   0.6717034347641041,
#   0.04740046825907533,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'sulphates']",
#   "['density', 'total sulfur dioxide']"): [0.6767676472663879,
#   0.6304794549942017,
#   0.6422765851020813,
#   0.6500775814056396,
#   0.675143837928772,
#   0.07037749850494217,
#   0.6717034347641041,
#   0.371260481285427,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'density']",
#   "['total sulfur dioxide', 'citric acid']"): [0.646237313747406,
#   0.6431003212928772,
#   0.6943721175193787,
#   0.6204681992530823,
#   0.6312757730484009,
#   0.07037749850494217,
#   0.18300566393215348,
#   0.200632326641512,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['density', 'citric acid']"): [0.6850217580795288,
#   0.6509367823600769,
#   0.6637496948242188,
#   0.6362560987472534,
#   0.6472264528274536,
#   0.07037749850494217,
#   0.18300566393215348,
#   0.04740046825907533,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'pH']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'citric acid']",
#   "['density', 'total sulfur dioxide']"): [0.6388841271400452,
#   0.6437161564826965,
#   0.6798118352890015,
#   0.6490954160690308,
#   0.6344226598739624,
#   0.07037749850494217,
#   0.18300566393215348,
#   0.2038229138290425,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'chlorides']",
#   "['density', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.6542887091636658,
#   0.6456910967826843,
#   0.6344873309135437,
#   0.6563093066215515,
#   0.6499202847480774,
#   -0.15379419286482485,
#   -0.2650261311732278,
#   0.07126947620310328,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'chlorides']",
#   "['density', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6194751858711243,
#   0.5970168709754944,
#   0.617895245552063,
#   0.6236937046051025,
#   0.617533802986145,
#   -0.15379419286482485,
#   -0.2650261311732278,
#   0.364947175211252,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'chlorides']",
#   "['density', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6753705739974976,
#   0.6502876281738281,
#   0.7315542697906494,
#   0.6656948328018188,
#   0.6910310387611389,
#   -0.15379419286482485,
#   -0.2650261311732278,
#   0.14850641172078524,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'density']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.6751216053962708,
#   0.6690414547920227,
#   0.6421555280685425,
#   0.7487238645553589,
#   0.6602540612220764,
#   -0.15379419286482485,
#   -0.3416993347850301,
#   0.04740046825907533,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'density']",
#   "['chlorides', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6488226652145386,
#   0.636003851890564,
#   0.6407691240310669,
#   0.6265653371810913,
#   0.6266976594924927,
#   -0.15379419286482485,
#   -0.3416993347850301,
#   0.2038229138290425,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'density']",
#   "['chlorides', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.634381890296936,
#   0.6740238666534424,
#   0.6191080808639526,
#   0.6619371175765991,
#   0.7375466227531433,
#   -0.15379419286482485,
#   -0.3416993347850301,
#   0.371260481285427,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'total sulfur dioxide']",
#   "['chlorides', 'density']",
#   "['citric acid', 'sulphates']"): [0.63519686460495,
#   0.6373197436332703,
#   0.6710243225097656,
#   0.64081209897995,
#   0.6580489873886108,
#   -0.15379419286482485,
#   -0.06649455901285606,
#   0.200632326641512,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'total sulfur dioxide']",
#   "['chlorides', 'citric acid']",
#   "['density', 'sulphates']"): [0.6679883003234863,
#   0.6706282496452332,
#   0.6361097097396851,
#   0.6269141435623169,
#   0.6691380739212036,
#   -0.15379419286482485,
#   -0.06649455901285606,
#   0.2038229138290425,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'total sulfur dioxide']",
#   "['chlorides', 'sulphates']",
#   "['density', 'citric acid']"): [0.6344130635261536,
#   0.6434124112129211,
#   0.6523187160491943,
#   0.6515495181083679,
#   0.6478014588356018,
#   -0.15379419286482485,
#   -0.06649455901285606,
#   0.371260481285427,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'citric acid']",
#   "['chlorides', 'density']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6137692332267761,
#   0.6290549039840698,
#   0.622789740562439,
#   0.6250687837600708,
#   0.6040478944778442,
#   -0.15379419286482485,
#   -0.5419041447395132,
#   0.200632326641512,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'citric acid']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['density', 'sulphates']"): [0.6373555660247803,
#   0.6508482694625854,
#   0.6776196360588074,
#   0.6437708139419556,
#   0.6500312089920044,
#   -0.15379419286482485,
#   -0.5419041447395132,
#   0.04740046825907533,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'citric acid']",
#   "['chlorides', 'sulphates']",
#   "['density', 'total sulfur dioxide']"): [0.6461248397827148,
#   0.6577922701835632,
#   0.6563075184822083,
#   0.6742207407951355,
#   0.6398416757583618,
#   -0.15379419286482485,
#   -0.5419041447395132,
#   0.371260481285427,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'sulphates']",
#   "['chlorides', 'density']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6405400633811951,
#   0.6266573071479797,
#   0.6419345736503601,
#   0.6474735736846924,
#   0.662326455116272,
#   -0.15379419286482485,
#   -0.1966476023043703,
#   0.200632326641512,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'sulphates']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['density', 'citric acid']"): [0.6359699964523315,
#   0.6387443542480469,
#   0.6425802111625671,
#   0.6414375901222229,
#   0.6825698614120483,
#   -0.15379419286482485,
#   -0.1966476023043703,
#   0.04740046825907533,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'fixed acidity']",
#   "['pH', 'sulphates']",
#   "['chlorides', 'citric acid']",
#   "['density', 'total sulfur dioxide']"): [0.6341782808303833,
#   0.6485176682472229,
#   0.6642275452613831,
#   0.6574879884719849,
#   0.6786183714866638,
#   -0.15379419286482485,
#   -0.1966476023043703,
#   0.2038229138290425,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'fixed acidity']",
#   "['density', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.6355162858963013,
#   0.631607711315155,
#   0.6680585145950317,
#   0.6242446303367615,
#   0.6334277391433716,
#   0.005562147004781117,
#   -0.6829781945685299,
#   0.07126947620310328,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'fixed acidity']",
#   "['density', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6233963966369629,
#   0.5989766120910645,
#   0.622248649597168,
#   0.6304145455360413,
#   0.6025397181510925,
#   0.005562147004781117,
#   -0.6829781945685299,
#   0.364947175211252,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'fixed acidity']",
#   "['density', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6498143672943115,
#   0.6446458101272583,
#   0.6407536268234253,
#   0.6507641077041626,
#   0.6273505091667175,
#   0.005562147004781117,
#   -0.6829781945685299,
#   0.14850641172078524,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'density']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.648051381111145,
#   0.6430574655532837,
#   0.6581648588180542,
#   0.6757243871688843,
#   0.6470600962638855,
#   0.005562147004781117,
#   -0.3416993347850301,
#   -0.11318144304548039,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'density']",
#   "['fixed acidity', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6602427959442139,
#   0.6448339819908142,
#   0.633520781993866,
#   0.6435467004776001,
#   0.6325241327285767,
#   0.005562147004781117,
#   -0.3416993347850301,
#   0.6717034347641041,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'density']",
#   "['fixed acidity', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6177043318748474,
#   0.6761503219604492,
#   0.6330030560493469,
#   0.6448264122009277,
#   0.6264511346817017,
#   0.005562147004781117,
#   -0.3416993347850301,
#   0.18300566393215348,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'density']",
#   "['citric acid', 'sulphates']"): [0.6290735006332397,
#   0.6566615104675293,
#   0.6264687776565552,
#   0.6553277969360352,
#   0.6602669954299927,
#   0.005562147004781117,
#   -0.06649455901285606,
#   0.6680472921189711,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'citric acid']",
#   "['density', 'sulphates']"): [0.6303797960281372,
#   0.6537033319473267,
#   0.6418401002883911,
#   0.6568433046340942,
#   0.6928465366363525,
#   0.005562147004781117,
#   -0.06649455901285606,
#   0.6717034347641041,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'sulphates']",
#   "['density', 'citric acid']"): [0.6430037617683411,
#   0.6541590094566345,
#   0.6496052742004395,
#   0.6562375426292419,
#   0.6585243940353394,
#   0.005562147004781117,
#   -0.06649455901285606,
#   0.18300566393215348,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'density']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6423894166946411,
#   0.626649022102356,
#   0.6414979100227356,
#   0.6264813542366028,
#   0.6282449960708618,
#   0.005562147004781117,
#   -0.5419041447395132,
#   0.6680472921189711,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['density', 'sulphates']"): [0.6412864923477173,
#   0.6367460489273071,
#   0.6500449180603027,
#   0.6417993307113647,
#   0.6465783715248108,
#   0.005562147004781117,
#   -0.5419041447395132,
#   -0.11318144304548039,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'sulphates']",
#   "['density', 'total sulfur dioxide']"): [0.655634880065918,
#   0.6662961840629578,
#   0.6488290429115295,
#   0.6827357411384583,
#   0.6571311950683594,
#   0.005562147004781117,
#   -0.5419041447395132,
#   0.18300566393215348,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'density']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6544402837753296,
#   0.6254788041114807,
#   0.6313185691833496,
#   0.6175580024719238,
#   0.6755555868148804,
#   0.005562147004781117,
#   -0.1966476023043703,
#   0.6680472921189711,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['density', 'citric acid']"): [0.6533916592597961,
#   0.6348122358322144,
#   0.6334511041641235,
#   0.6392459869384766,
#   0.6551393866539001,
#   0.005562147004781117,
#   -0.1966476023043703,
#   -0.11318144304548039,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'chlorides']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'citric acid']",
#   "['density', 'total sulfur dioxide']"): [0.6318429112434387,
#   0.6624950170516968,
#   0.6814687252044678,
#   0.6513747572898865,
#   0.6637427806854248,
#   0.005562147004781117,
#   -0.1966476023043703,
#   0.6717034347641041,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.6541358232498169,
#   0.6688181757926941,
#   0.6320164799690247,
#   0.6466902494430542,
#   0.6442838907241821,
#   -0.021945831163489242,
#   -0.6829781945685299,
#   0.04740046825907533,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6646822094917297,
#   0.6338242292404175,
#   0.6121110916137695,
#   0.6132993698120117,
#   0.6155710816383362,
#   -0.021945831163489242,
#   -0.6829781945685299,
#   0.2038229138290425,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6269443035125732,
#   0.6526805758476257,
#   0.6268349885940552,
#   0.607193112373352,
#   0.6364961862564087,
#   -0.021945831163489242,
#   -0.6829781945685299,
#   0.371260481285427,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['citric acid', 'sulphates']"): [0.6577531695365906,
#   0.6518779993057251,
#   0.638261616230011,
#   0.6403223276138306,
#   0.6692834496498108,
#   -0.021945831163489242,
#   -0.2650261311732278,
#   -0.11318144304548039,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'citric acid']",
#   "['total sulfur dioxide', 'sulphates']"): [0.641788125038147,
#   0.6377261877059937,
#   0.601615309715271,
#   0.6362091898918152,
#   0.6178191900253296,
#   -0.021945831163489242,
#   -0.2650261311732278,
#   0.6717034347641041,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'sulphates']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6638296246528625,
#   0.6337721943855286,
#   0.6236933469772339,
#   0.677768349647522,
#   0.6098151206970215,
#   -0.021945831163489242,
#   -0.2650261311732278,
#   0.18300566393215348,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'chlorides']",
#   "['citric acid', 'sulphates']"): [0.6472376585006714,
#   0.6307924389839172,
#   0.6385549306869507,
#   0.6421335935592651,
#   0.6235779523849487,
#   -0.021945831163489242,
#   -0.06649455901285606,
#   0.093705186321305,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'sulphates']"): [0.6417436003684998,
#   0.6394709348678589,
#   0.6304876208305359,
#   0.6373477578163147,
#   0.6438930034637451,
#   -0.021945831163489242,
#   -0.06649455901285606,
#   0.6717034347641041,
#   0.371260481285427],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'citric acid']"): [0.6460332274436951,
#   0.6411857008934021,
#   0.6378509402275085,
#   0.6412695050239563,
#   0.7580798864364624,
#   -0.021945831163489242,
#   -0.06649455901285606,
#   0.18300566393215348,
#   0.2038229138290425],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'chlorides']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6221032738685608,
#   0.6147750020027161,
#   0.6115425825119019,
#   0.657991886138916,
#   0.6737962961196899,
#   -0.021945831163489242,
#   -0.5419041447395132,
#   0.093705186321305,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'sulphates']"): [0.6325300931930542,
#   0.6529721617698669,
#   0.6750338077545166,
#   0.6648498773574829,
#   0.6426963806152344,
#   -0.021945831163489242,
#   -0.5419041447395132,
#   -0.11318144304548039,
#   0.371260481285427],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'total sulfur dioxide']"): [0.6418359875679016,
#   0.6188398599624634,
#   0.6310365200042725,
#   0.6418975591659546,
#   0.6728125810623169,
#   -0.021945831163489242,
#   -0.5419041447395132,
#   0.18300566393215348,
#   0.04740046825907533],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'chlorides']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6076172590255737,
#   0.6291725039482117,
#   0.6455992460250854,
#   0.6196268796920776,
#   0.6257525682449341,
#   -0.021945831163489242,
#   -0.1966476023043703,
#   0.093705186321305,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'citric acid']"): [0.6559202075004578,
#   0.6350712776184082,
#   0.6495851874351501,
#   0.6430143713951111,
#   0.6614623069763184,
#   -0.021945831163489242,
#   -0.1966476023043703,
#   -0.11318144304548039,
#   0.2038229138290425],
#  ("['free sulfur dioxide', 'density']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'total sulfur dioxide']"): [0.7027508616447449,
#   0.6396940350532532,
#   0.6660962700843811,
#   0.646084189414978,
#   0.6423894166946411,
#   -0.021945831163489242,
#   -0.1966476023043703,
#   0.6717034347641041,
#   0.04740046825907533],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'density']",
#   "['citric acid', 'sulphates']"): [0.6346330642700195,
#   0.6451194882392883,
#   0.6705582737922668,
#   0.6641167402267456,
#   0.6621794700622559,
#   0.6676664504810212,
#   -0.6829781945685299,
#   0.200632326641512,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'citric acid']",
#   "['density', 'sulphates']"): [0.7070132493972778,
#   0.6561323404312134,
#   0.6409854888916016,
#   0.6854058504104614,
#   0.6461939811706543,
#   0.6676664504810212,
#   -0.6829781945685299,
#   0.2038229138290425,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'sulphates']",
#   "['density', 'citric acid']"): [0.651893675327301,
#   0.640468955039978,
#   0.6589623689651489,
#   0.6333013772964478,
#   0.6392191052436829,
#   0.6676664504810212,
#   -0.6829781945685299,
#   0.371260481285427,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'density']",
#   "['citric acid', 'sulphates']"): [0.6468192338943481,
#   0.6491069793701172,
#   0.6473281979560852,
#   0.6406663656234741,
#   0.6523345112800598,
#   0.6676664504810212,
#   -0.2650261311732278,
#   0.6680472921189711,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'citric acid']",
#   "['density', 'sulphates']"): [0.6728049516677856,
#   0.6848793029785156,
#   0.6375073194503784,
#   0.6479328274726868,
#   0.6670910716056824,
#   0.6676664504810212,
#   -0.2650261311732278,
#   0.6717034347641041,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'sulphates']",
#   "['density', 'citric acid']"): [0.6591193675994873,
#   0.6438786387443542,
#   0.6315202116966248,
#   0.6799591183662415,
#   0.6446961760520935,
#   0.6676664504810212,
#   -0.2650261311732278,
#   0.18300566393215348,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'density']",
#   "['fixed acidity', 'chlorides']",
#   "['citric acid', 'sulphates']"): [0.654091477394104,
#   0.6249905824661255,
#   0.6709542274475098,
#   0.6329637765884399,
#   0.6547172665596008,
#   0.6676664504810212,
#   -0.3416993347850301,
#   0.093705186321305,
#   0.31277004385441737],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'density']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'sulphates']"): [0.6790591478347778,
#   0.6428439617156982,
#   0.6517024040222168,
#   0.6490181684494019,
#   0.6639289855957031,
#   0.6676664504810212,
#   -0.3416993347850301,
#   0.6717034347641041,
#   0.371260481285427],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'density']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'citric acid']"): [0.7689369320869446,
#   0.6632515788078308,
#   0.6706429123878479,
#   0.6544179916381836,
#   0.627975583076477,
#   0.6676664504810212,
#   -0.3416993347850301,
#   0.18300566393215348,
#   0.2038229138290425],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'sulphates']"): [0.6710618138313293,
#   0.6661598086357117,
#   0.6567050218582153,
#   0.6566879153251648,
#   0.6707677841186523,
#   0.6676664504810212,
#   -0.5419041447395132,
#   0.093705186321305,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'sulphates']"): [0.690712571144104,
#   0.648556113243103,
#   0.6602290272712708,
#   0.6611717939376831,
#   0.6848737001419067,
#   0.6676664504810212,
#   -0.5419041447395132,
#   0.6680472921189711,
#   0.371260481285427],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'density']"): [0.6515836119651794,
#   0.6503170132637024,
#   0.6313392519950867,
#   0.638687014579773,
#   0.640705406665802,
#   0.6676664504810212,
#   -0.5419041447395132,
#   0.18300566393215348,
#   0.200632326641512],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'citric acid']"): [0.6664730310440063,
#   0.6465915441513062,
#   0.6358420252799988,
#   0.6366986036300659,
#   0.6522278189659119,
#   0.6676664504810212,
#   -0.1966476023043703,
#   0.093705186321305,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'citric acid']"): [0.6537458300590515,
#   0.6516138315200806,
#   0.6432700157165527,
#   0.7581192255020142,
#   0.6799579858779907,
#   0.6676664504810212,
#   -0.1966476023043703,
#   0.6680472921189711,
#   0.2038229138290425],
#  ("['free sulfur dioxide', 'total sulfur dioxide']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'density']"): [0.6656194925308228,
#   0.6469901204109192,
#   0.6789087057113647,
#   0.6558200120925903,
#   0.6576499938964844,
#   0.6676664504810212,
#   -0.1966476023043703,
#   0.6717034347641041,
#   0.200632326641512],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'density']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6332117319107056,
#   0.6420347094535828,
#   0.6281734704971313,
#   0.6083906888961792,
#   0.6030422449111938,
#   -0.06097812919230497,
#   -0.6829781945685299,
#   0.200632326641512,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['density', 'sulphates']"): [0.6269901394844055,
#   0.6469700932502747,
#   0.6674982309341431,
#   0.6274831295013428,
#   0.6377525925636292,
#   -0.06097812919230497,
#   -0.6829781945685299,
#   0.04740046825907533,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'sulphates']",
#   "['density', 'total sulfur dioxide']"): [0.6456114649772644,
#   0.6456401944160461,
#   0.6626272797584534,
#   0.6246532797813416,
#   0.6229118704795837,
#   -0.06097812919230497,
#   -0.6829781945685299,
#   0.371260481285427,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'density']",
#   "['total sulfur dioxide', 'sulphates']"): [0.605782151222229,
#   0.6141195297241211,
#   0.6208702325820923,
#   0.6018626093864441,
#   0.6517705917358398,
#   -0.06097812919230497,
#   -0.2650261311732278,
#   0.6680472921189711,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['density', 'sulphates']"): [0.6375108957290649,
#   0.6318603754043579,
#   0.63344806432724,
#   0.6348891258239746,
#   0.6515604853630066,
#   -0.06097812919230497,
#   -0.2650261311732278,
#   -0.11318144304548039,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'sulphates']",
#   "['density', 'total sulfur dioxide']"): [0.6413782835006714,
#   0.675049364566803,
#   0.6432298421859741,
#   0.6492300033569336,
#   0.606802761554718,
#   -0.06097812919230497,
#   -0.2650261311732278,
#   0.18300566393215348,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'density']",
#   "['fixed acidity', 'chlorides']",
#   "['total sulfur dioxide', 'sulphates']"): [0.6123992204666138,
#   0.6549326181411743,
#   0.6030589938163757,
#   0.6016777157783508,
#   0.6408998966217041,
#   -0.06097812919230497,
#   -0.3416993347850301,
#   0.093705186321305,
#   0.04294683623953844],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'density']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'sulphates']"): [0.6666216254234314,
#   0.634954571723938,
#   0.6582270860671997,
#   0.6705281138420105,
#   0.6564643979072571,
#   -0.06097812919230497,
#   -0.3416993347850301,
#   -0.11318144304548039,
#   0.371260481285427],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'density']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'total sulfur dioxide']"): [0.6336793303489685,
#   0.6343379616737366,
#   0.6238022446632385,
#   0.6297287940979004,
#   0.6162775158882141,
#   -0.06097812919230497,
#   -0.3416993347850301,
#   0.18300566393215348,
#   0.04740046825907533],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'sulphates']"): [0.6483827829360962,
#   0.6657224893569946,
#   0.643616259098053,
#   0.6256468296051025,
#   0.6256535649299622,
#   -0.06097812919230497,
#   -0.06649455901285606,
#   0.093705186321305,
#   0.14850641172078524],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'sulphates']"): [0.6546394228935242,
#   0.6492824554443359,
#   0.7583452463150024,
#   0.642359733581543,
#   0.6440319418907166,
#   -0.06097812919230497,
#   -0.06649455901285606,
#   0.6680472921189711,
#   0.371260481285427],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'sulphates']",
#   "['chlorides', 'density']"): [0.6393753290176392,
#   0.6059590578079224,
#   0.6462255716323853,
#   0.640245795249939,
#   0.6242960691452026,
#   -0.06097812919230497,
#   -0.06649455901285606,
#   0.18300566393215348,
#   0.200632326641512],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'total sulfur dioxide']"): [0.6431516408920288,
#   0.6306828260421753,
#   0.6608285307884216,
#   0.6517890095710754,
#   0.6627732515335083,
#   -0.06097812919230497,
#   -0.1966476023043703,
#   0.093705186321305,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'total sulfur dioxide']"): [0.6984440684318542,
#   0.6231817007064819,
#   0.6460458636283875,
#   0.6610010862350464,
#   0.6395257711410522,
#   -0.06097812919230497,
#   -0.1966476023043703,
#   0.6680472921189711,
#   0.04740046825907533],
#  ("['free sulfur dioxide', 'citric acid']",
#   "['pH', 'sulphates']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'density']"): [0.6340427994728088,
#   0.6589314937591553,
#   0.6515532732009888,
#   0.6380516886711121,
#   0.6964232325553894,
#   -0.06097812919230497,
#   -0.1966476023043703,
#   -0.11318144304548039,
#   0.200632326641512],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'density']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6232524514198303,
#   0.6227840781211853,
#   0.6152283549308777,
#   0.6170481443405151,
#   0.6509626507759094,
#   0.051657571842828584,
#   -0.6829781945685299,
#   0.200632326641512,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'total sulfur dioxide']",
#   "['density', 'citric acid']"): [0.6308462619781494,
#   0.642379879951477,
#   0.6544044017791748,
#   0.6379093527793884,
#   0.615324854850769,
#   0.051657571842828584,
#   -0.6829781945685299,
#   0.04740046825907533,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'fixed acidity']",
#   "['chlorides', 'citric acid']",
#   "['density', 'total sulfur dioxide']"): [0.6504075527191162,
#   0.6401320695877075,
#   0.6159368753433228,
#   0.6530228853225708,
#   0.6387055516242981,
#   0.051657571842828584,
#   -0.6829781945685299,
#   0.2038229138290425,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'density']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6293196678161621,
#   0.631841778755188,
#   0.6279517412185669,
#   0.6285490393638611,
#   0.6331228017807007,
#   0.051657571842828584,
#   -0.2650261311732278,
#   0.6680472921189711,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['density', 'citric acid']"): [0.6564615368843079,
#   0.6271865367889404,
#   0.6612873673439026,
#   0.6497240662574768,
#   0.6438220739364624,
#   0.051657571842828584,
#   -0.2650261311732278,
#   -0.11318144304548039,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'chlorides']",
#   "['fixed acidity', 'citric acid']",
#   "['density', 'total sulfur dioxide']"): [0.633858323097229,
#   0.6337019801139832,
#   0.6260913610458374,
#   0.6907467842102051,
#   0.6415808796882629,
#   0.051657571842828584,
#   -0.2650261311732278,
#   0.6717034347641041,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'density']",
#   "['fixed acidity', 'chlorides']",
#   "['total sulfur dioxide', 'citric acid']"): [0.6133400797843933,
#   0.62483811378479,
#   0.650330662727356,
#   0.6571340560913086,
#   0.6249400973320007,
#   0.051657571842828584,
#   -0.3416993347850301,
#   0.093705186321305,
#   0.035533023931161666],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'density']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'citric acid']"): [0.6505768895149231,
#   0.6431777477264404,
#   0.6243062019348145,
#   0.6507745981216431,
#   0.6307412385940552,
#   0.051657571842828584,
#   -0.3416993347850301,
#   -0.11318144304548039,
#   0.2038229138290425],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'density']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'total sulfur dioxide']"): [0.6489013433456421,
#   0.7298663258552551,
#   0.6278010606765747,
#   0.6484752893447876,
#   0.641666054725647,
#   0.051657571842828584,
#   -0.3416993347850301,
#   0.6717034347641041,
#   0.04740046825907533],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'citric acid']"): [0.6414570808410645,
#   0.6575617790222168,
#   0.6385120153427124,
#   0.6107745170593262,
#   0.6216679215431213,
#   0.051657571842828584,
#   -0.06649455901285606,
#   0.093705186321305,
#   0.364947175211252],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'citric acid']"): [0.7567833662033081,
#   0.6534559726715088,
#   0.6560615301132202,
#   0.6309497952461243,
#   0.6399073600769043,
#   0.051657571842828584,
#   -0.06649455901285606,
#   0.6680472921189711,
#   0.2038229138290425],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'total sulfur dioxide']",
#   "['fixed acidity', 'citric acid']",
#   "['chlorides', 'density']"): [0.6361597776412964,
#   0.6604970693588257,
#   0.628572940826416,
#   0.6680687665939331,
#   0.6481953859329224,
#   0.051657571842828584,
#   -0.06649455901285606,
#   0.6717034347641041,
#   0.200632326641512],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'chlorides']",
#   "['density', 'total sulfur dioxide']"): [0.6594619154930115,
#   0.6496044397354126,
#   0.6567026376724243,
#   0.6426337957382202,
#   0.6310402154922485,
#   0.051657571842828584,
#   -0.5419041447395132,
#   0.093705186321305,
#   0.07126947620310328],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'density']",
#   "['chlorides', 'total sulfur dioxide']"): [0.6315862536430359,
#   0.6570826768875122,
#   0.6765316128730774,
#   0.6402273774147034,
#   0.6633884310722351,
#   0.051657571842828584,
#   -0.5419041447395132,
#   0.6680472921189711,
#   0.04740046825907533],
#  ("['free sulfur dioxide', 'sulphates']",
#   "['pH', 'citric acid']",
#   "['fixed acidity', 'total sulfur dioxide']",
#   "['chlorides', 'density']"): [0.6187930107116699,
#   0.6369686722755432,
#   0.7546535730361938,
#   0.6389029026031494,
#   0.6282389760017395,
#   0.051657571842828584,
#   -0.5419041447395132,
#   -0.11318144304548039,
#   0.200632326641512]}
