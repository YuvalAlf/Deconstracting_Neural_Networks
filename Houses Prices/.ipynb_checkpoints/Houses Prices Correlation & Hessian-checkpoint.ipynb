# %%
import numpy as np
import seaborn as sns
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import tree
from keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.neighbors import KNeighborsRegressor
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping
from keras.models import load_model
from numpy.random import seed
from statsmodels.stats.multitest import multipletests
from scipy.stats import ranksums
from more_itertools import powerset

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'    

pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

sns.set()
warnings.filterwarnings('ignore')
random_seed = 10000
seed(random_seed)

# %%
df = pd.read_csv('houses_dataset.csv', index_col = 'Id')
df = df._get_numeric_data()
df = df.dropna(axis='columns')
df_rows = df.shape[0]
zero_precents = df.astype(bool).apply(lambda x: ~x).sum(axis = 0) / df_rows
zero_columns_labels = list(zero_precents[zero_precents > 0.333].index)
df = df.drop(zero_columns_labels, axis = 1)
df = df.drop(['KitchenAbvGr'], axis = 1)
df.head(10)
# Out:
#     MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1           60     8450            7            5       2003          2003
# 2           20     9600            6            8       1976          1976
# 3           60    11250            7            5       2001          2002
# 4           70     9550            7            5       1915          1970
# 5           60    14260            8            5       2000          2000
# 6           50    14115            5            5       1993          1995
# 7           20    10084            8            5       2004          2005
# 8           60    10382            7            6       1973          1973
# 9           50     6120            7            5       1931          1950
# 10         190     7420            5            6       1939          1950
#
#     BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  \
# Id
# 1          706        150          856       856       1710         2
# 2          978        284         1262      1262       1262         2
# 3          486        434          920       920       1786         2
# 4          216        540          756       961       1717         1
# 5          655        490         1145      1145       2198         2
# 6          732         64          796       796       1362         1
# 7         1369        317         1686      1694       1694         2
# 8          859        216         1107      1107       2090         2
# 9            0        952          952      1022       1774         2
# 10         851        140          991      1077       1077         1
#
#     BedroomAbvGr  TotRmsAbvGrd  GarageCars  GarageArea  MoSold  YrSold  \
# Id
# 1              3             8           2         548       2    2008
# 2              3             6           2         460       5    2007
# 3              3             6           2         608       9    2008
# 4              3             7           3         642       2    2006
# 5              4             9           3         836      12    2008
# 6              1             5           2         480      10    2009
# 7              3             7           2         636       8    2007
# 8              3             7           2         484      11    2009
# 9              2             8           2         468       4    2008
# 10             2             5           1         205       1    2008
#
#     SalePrice
# Id
# 1      208500
# 2      181500
# 3      223500
# 4      140000
# 5      250000
# 6      143000
# 7      307000
# 8      200000
# 9      129900
# 10     118000

# %% [markdown]
# ## Correlation to Sale-Price

# %%
correlation = df.corr()['SalePrice'].sort_values()
dd = pd.DataFrame(correlation)
chart = sns.barplot(correlation.index, correlation.values, palette="Blues_d")
_ = chart.set_xticklabels(chart.get_xticklabels(), rotation=90)

# %%
top_8_cats = abs(df.corr())['SalePrice'].sort_values(ascending=False)[1:(1+8)]
for cat in top_8_cats.index:
    print(cat)
data = df[list(top_8_cats.index) + ["SalePrice"]]
# Out:
# OverallQual
# GrLivArea
# GarageCars
# GarageArea
# TotalBsmtSF
# 1stFlrSF
# FullBath
# TotRmsAbvGrd

# %% [markdown]
# ## Visualization

# %%
_ = sns.pairplot(data=data, y_vars=['SalePrice'], x_vars=data.columns, kind="reg", diag_kind="kde", plot_kws={'line_kws':{'color':'purple'}, 'scatter_kws': {'alpha': 0.2}})

# %% [markdown]
# # Correlation Heatmap

# %%
_ = sns.heatmap(data.corr(), cmap="BrBG", linewidths = 1, vmin = -1, vmax = 1, annot = True)

# %% [markdown]
# # Neural Network Training

# %%
test_precent = 0.15
train_precent = 1.0 - test_precent
train_data = data.sample(frac=train_precent, random_state=random_seed)
test_data = data.drop(train_data.index)

# %%
train_stats = train_data.describe().T
def normalize(x):
    result = x.copy()
    for feature_name in x.columns:
        average = x[feature_name].mean()
        std = x[feature_name].std()
        result[feature_name] = (x[feature_name] - average) / std
    return result
normalized_train_data = normalize(train_data)
normalized_test_data = normalize(test_data)
normalized_train_data.head()
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# Id
# 1356     0.643370   0.746126    0.291487    0.043976    -1.103240  0.130061
# 1141    -0.801738  -1.073912    0.291487    1.708025    -0.254483 -0.554142
# 491     -0.801738  -0.412080   -1.063329   -0.667841    -1.783135 -1.405594
# 449     -0.079184  -0.276705   -1.063329   -1.318376    -0.636646 -0.990004
# 358     -0.801738  -0.716673    0.291487    0.237251     0.167674 -0.072666
#
#       FullBath  TotRmsAbvGrd  SalePrice
# Id
# 1356  2.583995      0.903746  -0.150385
# 1141 -1.041486     -1.559842  -0.530158
# 491  -1.041486     -1.559842  -0.824177
# 449   0.771255      0.287849  -0.769048
# 358  -1.041486     -0.328048  -0.591412

# %%
train_x = normalized_train_data.drop('SalePrice', axis = 1)
train_y = normalized_train_data['SalePrice']
test_x = normalized_test_data.drop('SalePrice', axis = 1)
test_y = normalized_test_data['SalePrice']

# %%
def build_fully_NN_model(train):
    input_layer    = Input(shape=(train.shape[1],))
    hidden_layer_1 = Dense(8, activation=tf.nn.relu)(input_layer)
    hidden_layer_2 = Dense(8, activation=tf.nn.relu)(hidden_layer_1)
    output_layer   = Dense(1)(hidden_layer_2)
   
    model = Model(input=[input_layer], output=[output_layer])
    last_layer_model = Model(input=[input_layer], output=[hidden_layer_2])
    
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    

    return model, last_layer_model

# %%
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

def trainModel(model, X, Y):
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=50)
    mc = ModelCheckpoint('best_nn_model.nn', monitor='val_loss', mode='min', verbose=0, save_best_only=True)
    history = model.fit(X, Y, epochs=400, validation_split = 0.33, verbose=0, callbacks=[PrintDot(), es, mc])
    model = load_model('best_nn_model.nn')
    return history, model

# %%
fully_NN_model, last_layer_NN_model = build_fully_NN_model(train_x)
fully_NN_history, fully_NN_model = trainModel(fully_NN_model, train_x, train_y)
# Out:
# ....................................................................................................
# ............................................................

# %%
def plot_history(history):    
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch 
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mean_squared_error'], label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'], label = 'Validation Error')
  #plt.ylim([0,1000])
  plt.legend()
  plt.show()

plot_history(fully_NN_history)

# %% [markdown]
# ## Test Set

# %%
def show_test_predictions(name, model, test_X, test_Y):
    loss, mse = model.evaluate(test_X, test_Y, verbose=0)
    print(name + ' MSE = ' + str(mse))
    test_predictions = model.predict(test_X).flatten()

    plt.scatter(test_Y, test_predictions, alpha = 0.4, color = 'salmon')
    plt.xlabel('True Values [MPG]')
    plt.ylabel('Predictions [MPG]')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim([-10,10])
    plt.ylim([-10,10])
    _ = plt.plot([-5, 5], [-5, 5], color = 'black')
show_test_predictions('Test Set', fully_NN_model, test_x, test_y)
# Out:
# Test Set MSE = 0.14252491295337677

# %% [markdown]
# ## Train Set

# %%
def show_test_predictions(name, model, testX, testY):
    loss, mse = model.evaluate(testX, testY, verbose=0)
    print(name + ' MSE = ' + str(mse))
    test_predictions = model.predict(testX).flatten()

    plt.scatter(testY, test_predictions, alpha = 0.15, color = 'purple')
    plt.xlabel('True Values [MPG]')
    plt.ylabel('Predictions [MPG]')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim([-10,10])
    plt.ylim([-10,10])
    _ = plt.plot([-5, 5], [-5, 5], color = 'black')
show_test_predictions('Train Set', fully_NN_model, train_x, train_y)
# Out:
# Train Set MSE = 0.15862925350666046

# %%
def evaluate(model, input_data):
    return model.predict(np.array([input_data]))[0][0]

def copy_and_add(data_list, dim_1, amount_1, dim_2, amount_2):
    data_list = data_list.copy()
    data_list[dim_1] += amount_1
    data_list[dim_2] += amount_2
    return data_list

def get_second_derivative(model, input_data, dim_1, dim_2):
    eps = 0.1
    f_pp = evaluate(model, copy_and_add(input_data, dim_1, eps, dim_2, eps))
    f_mm = evaluate(model, copy_and_add(input_data, dim_1, -eps, dim_2, -eps))
    f_mp = evaluate(model, copy_and_add(input_data, dim_1, -eps, dim_2, eps))
    f_pm = evaluate(model, copy_and_add(input_data, dim_1, eps, dim_2, -eps))
    real_sec_dev = (f_pp + f_mm - f_mp - f_pm) / (4*eps*eps)
    direction_dev = (f_pp - f_mm) / (4*eps*eps)
    mixed_direction_dev = (f_pm - f_mp) / (4*eps*eps)
    return real_sec_dev, direction_dev, mixed_direction_dev

def input_data_options(list_data):
    if (len(list_data) == 8):
        yield list_data
    else:
        for option in [0.3, 0.7]:
            list_data.append(option)
            for inner_res in input_data_options(list_data):
                yield inner_res
            list_data.pop()
sec_dev_table = np.zeros((8,8))
abs_sec_dev_table = np.zeros((8,8))
direction_dev_table = np.zeros((8,8))
abs_direction_dev_table = np.zeros((8,8))
mixed_direction_dev_table = np.zeros((8,8))
abs_mixed_direction_dev_table = np.zeros((8,8))
items_amount = 0
for input_data in input_data_options([]):
    items_amount += 1
    if (items_amount % 10 == 0):
        print('.', end='')
    for dim_1 in range(8):
        for dim_2 in range(8):
            real_sec_dev, direction_dev, mixed_direction_dev = get_second_derivative(fully_NN_model, input_data, dim_1, dim_2)
            sec_dev_table[dim_1, dim_2] += real_sec_dev
            abs_sec_dev_table[dim_1, dim_2] += abs(real_sec_dev)
            direction_dev_table[dim_1, dim_2] += direction_dev
            abs_direction_dev_table[dim_1, dim_2] += abs(direction_dev)
            mixed_direction_dev_table[dim_1, dim_2] += mixed_direction_dev
            abs_mixed_direction_dev_table[dim_1, dim_2] += abs(mixed_direction_dev)
sec_dev_table /= items_amount
abs_sec_dev_table /= items_amount
direction_dev_table /= items_amount
abs_direction_dev_table /= items_amount
mixed_direction_dev_table /= items_amount
abs_mixed_direction_dev_table /= items_amount
# Out:
# .........................

# %% [markdown]
# # Hessian f(x+e,y+e)+f(x-e,y-e)-f(x+e,y-e)-f(x-e,y+e)

# %%
def to_df(hess_table):
    names = data.corr().columns[:8]
    hessian_df = pd.DataFrame(hess_table, index = names, columns=names)
    return hessian_df

def display_heatmap(hess):
    hessian_df = to_df(hess)
    min_val = hessian_df.min().min()
    max_val = hessian_df.max().max()
    _ = sns.heatmap(hessian_df, cmap="BrBG", linewidths = 1, vmin = min_val, vmax = max_val, annot = True)
display_heatmap(sec_dev_table)

# %% [markdown]
# # Absolute Hessian |f(x+e,y+e)+f(x-e,y-e)-f(x+e,y-e)-f(x-e,y+e)|

# %%
display_heatmap(abs_sec_dev_table)

# %% [markdown]
# # Directional Derivative f(x+e,y+e)-f(x-e,y-e)

# %%
display_heatmap(direction_dev_table)

# %% [markdown]
# # Absolute Directional Derivative |f(x+e,y+e)-f(x-e,y-e)|

# %%
display_heatmap(abs_direction_dev_table)

# %% [markdown]
# # Mixed Directional Derivative f(x+e,y-e)-f(x-e,y+e)

# %%
display_heatmap(mixed_direction_dev_table)

# %% [markdown]
# # Absolute Mixed Directional Derivative |f(x+e,y-e)-f(x-e,y+e)|

# %%
display_heatmap(abs_mixed_direction_dev_table)

# %% [markdown]
# # Prametric-Rank-Sum

# %%
def perform_parametric_rank_sum(hess, name):
    hess = to_df(hess)
    n_inputs = hess.shape[0]
    inputs = set(hess.columns)
    partitions = [(set(partition), inputs - set(partition))
                      for partition in powerset(inputs)
                      if len(partition) >=2 and len(partition) <= n_inputs - 2 and 'OverallQual' in partition]
    
    def extract_triangle(cols):
        data = hess.loc[cols, cols]
        data = data.where(np.triu(np.ones(data.shape)).astype(bool)).stack().to_numpy()
        return data
    
    triangular_samples = [((group1, extract_triangle(group1)), (group2, extract_triangle(group2)))
                          for group1, group2 in partitions]
    rank_sum_pvalues = [(g1, g2, ranksums(x=g1_data, y=g2_data).pvalue)
                        for ((g1, g1_data), (g2, g2_data)) in triangular_samples]
    pvalues = list(map(lambda c: c[2], rank_sum_pvalues))
    alpha = 0.05
    rank_sum_pvalues_adj = multipletests(pvals=pvalues, is_sorted = False, method = 'holm-sidak', alpha = alpha)[1]
    results = [(tuple(g1), tuple(g2), orig_pval)
               for ((g1, g2, orig_pval), adj_pval) in zip(rank_sum_pvalues, rank_sum_pvalues_adj)]
    sorted_results = list(sorted(results, key = lambda x: x[2]))
    sorted_results = [sorted_results[i] + ((i + 1,)) for i in range(len(sorted_results))]
    return pd.DataFrame(sorted_results, columns=['group1', 'group2', name+'_pvalue', name+'_pvalue_rank'])

# %% [markdown]
# # Prametric-Rank-Sum Absolute Hessian

# %%
sec_dev_table_rank_sum = perform_parametric_rank_sum(sec_dev_table,'dv_dv')
abs_sec_dev_table_rank_sum = perform_parametric_rank_sum(abs_sec_dev_table,'|dv_dv|')
direction_dev_table_rank_sum = perform_parametric_rank_sum(direction_dev_table,'dir_dv')
abs_direction_dev_table_rank_sum = perform_parametric_rank_sum(abs_direction_dev_table,'|dir_dv|')
mixed_direction_dev_table_rank_sum = perform_parametric_rank_sum(mixed_direction_dev_table,'mixed_dir')
abs_mixed_direction_dev_table_rank_sum = perform_parametric_rank_sum(abs_mixed_direction_dev_table,'|mixed_dir|')

# %% [markdown]
# # Prametric-Rank-Sum Hessian

# %%
merged_parametric_rank_sum = \
    sec_dev_table_rank_sum.merge(abs_sec_dev_table_rank_sum, on=['group1','group2'], how='inner') \
                          .merge(direction_dev_table_rank_sum, on=['group1','group2'], how='inner') \
                          .merge(abs_direction_dev_table_rank_sum, on=['group1','group2'], how='inner') \
                          .merge(mixed_direction_dev_table_rank_sum, on=['group1','group2'], how='inner') \
                          .merge(abs_mixed_direction_dev_table_rank_sum, on=['group1','group2'], how='inner')

# %%
merged_parametric_rank_sum
# Out:
#                                                                           group1                                                                    group2  dv_dv_pvalue  dv_dv_pvalue_rank  |dv_dv|_pvalue  |dv_dv|_pvalue_rank  dir_dv_pvalue  dir_dv_pvalue_rank  |dir_dv|_pvalue  |dir_dv|_pvalue_rank  mixed_dir_pvalue  mixed_dir_pvalue_rank  |mixed_dir|_pvalue  |mixed_dir|_pvalue_rank
# 0    (1stFlrSF, GrLivArea, OverallQual, TotalBsmtSF, GarageArea, TotRmsAbvGrd)    (FullBath, GarageCars)                                                    0.010025      1                  0.126630        51                   0.088737       49                  0.406975         85                    0.205633          17                     0.176071            19
# 1    (GrLivArea, OverallQual)                                                     (1stFlrSF, FullBath, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)   0.020717      2                  0.007762        15                   0.005968       15                  0.005968         17                    0.631171          78                     0.176071            18
# 2    (1stFlrSF, GrLivArea, OverallQual, GarageCars, GarageArea, TotRmsAbvGrd)     (TotalBsmtSF, FullBath)                                                   0.026026      3                  0.040243        36                   0.275234       70                  0.694473         101                   0.827259          104                    0.275234            30
# 3    (1stFlrSF, GrLivArea, OverallQual, GarageArea, TotRmsAbvGrd)                 (TotalBsmtSF, FullBath, GarageCars)                                       0.029273      4                  0.029273        30                   0.212912       64                  0.483522         87                    0.668524          84                     0.413686            43
# 4    (GrLivArea, OverallQual, GarageCars)                                         (1stFlrSF, FullBath, TotalBsmtSF, GarageArea, TotRmsAbvGrd)               0.042960      5                  0.006435        13                   0.001077       5                   0.000815         6                     0.559305          67                     0.968950            114
# 5    (1stFlrSF, GrLivArea, OverallQual, TotalBsmtSF, TotRmsAbvGrd)                (GarageArea, FullBath, GarageCars)                                        0.051625      6                  0.391805        80                   0.006435       17                  0.029273         34                    0.413686          50                     0.149804            14
# 6    (TotalBsmtSF, GrLivArea, OverallQual)                                        (1stFlrSF, FullBath, GarageCars, GarageArea, TotRmsAbvGrd)                0.073366      7                  0.001414        5                    0.000460       3                   0.000460         3                     0.079839          8                      0.907038            97
# 7    (TotalBsmtSF, GrLivArea, OverallQual, GarageCars)                            (TotRmsAbvGrd, 1stFlrSF, GarageArea, FullBath)                            0.082099      8                  0.001499        6                    0.000157       1                   0.000157         1                     0.820596          103                    0.256839            23
# 8    (1stFlrSF, GrLivArea, OverallQual)                                           (FullBath, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)             0.086768      9                  0.212912        61                   0.002396       8                   0.005069         14                    0.149804          14                     0.968950            110
# 9    (1stFlrSF, GrLivArea, OverallQual, TotalBsmtSF, GarageArea)                  (TotRmsAbvGrd, FullBath, GarageCars)                                      0.086768      10                 0.533417        89                   0.003093       12                  0.019517         27                    0.413686          49                     0.198959            21
# 10   (1stFlrSF, GrLivArea, OverallQual, TotalBsmtSF)                              (TotRmsAbvGrd, GarageArea, FullBath, GarageCars)                          0.096304      11                 0.112411        49                   0.000212       2                   0.000507         5                     0.879829          108                    0.289918            32
# 11   (TotRmsAbvGrd, 1stFlrSF, GrLivArea, OverallQual)                             (TotalBsmtSF, GarageArea, FullBath, GarageCars)                           0.096304      12                 0.226476        64                   0.028366       30                  0.082099         46                    0.023342          1                      0.545350            53
# 12   (TotalBsmtSF, GarageArea, GrLivArea, OverallQual)                            (1stFlrSF, TotRmsAbvGrd, FullBath, GarageCars)                            0.096304      13                 0.019110        23                   0.001152       6                   0.001499         8                     0.198765          15                     0.325751            35
# 13   (TotRmsAbvGrd, GrLivArea, OverallQual)                                       (1stFlrSF, FullBath, GarageCars, TotalBsmtSF, GarageArea)                 0.102081      14                 0.640429        97                   0.015807       25                  0.012731         23                    0.293271          25                     0.968950            115
# 14   (GrLivArea, OverallQual, TotalBsmtSF, GarageArea, TotRmsAbvGrd)              (1stFlrSF, FullBath, GarageCars)                                          0.102081      15                 1.000000        119                  0.023968       29                  0.061707         42                    0.032284          3                      0.173080            17
# 15   (OverallQual, FullBath, GarageCars)                                          (1stFlrSF, GrLivArea, TotalBsmtSF, GarageArea, TotRmsAbvGrd)              0.119471      16                 0.008123        17                   0.640429       99                  0.242908         69                    0.907038          113                    0.845687            88
# 16   (1stFlrSF, GrLivArea, OverallQual, GarageCars)                               (TotRmsAbvGrd, TotalBsmtSF, GarageArea, FullBath)                         0.130570      17                 0.226476        63                   0.002497       10                  0.003197         13                    0.405679          43                     0.496292            50
# 17   (TotRmsAbvGrd, TotalBsmtSF, GrLivArea, OverallQual)                          (1stFlrSF, GarageArea, FullBath, GarageCars)                              0.130570      18                 0.364346        79                   0.002497       11                  0.002497         12                    0.041250          4                      0.256839            24
# 18   (TotRmsAbvGrd, GarageArea, GrLivArea, OverallQual)                           (1stFlrSF, TotalBsmtSF, FullBath, GarageCars)                             0.130570      19                 0.705457        104                  0.082099       47                  0.112411         52                    0.069642          7                      0.596701            60
# 19   (GarageArea, GrLivArea, OverallQual)                                         (1stFlrSF, FullBath, GarageCars, TotalBsmtSF, TotRmsAbvGrd)               0.139101      20                 0.042960        37                   0.010198       21                  0.008123         19                    0.258972          18                     0.907038            98
# 20   (1stFlrSF, GrLivArea, OverallQual, GarageCars, GarageArea)                   (TotalBsmtSF, TotRmsAbvGrd, FullBath)                                     0.139101      21                 0.876270        109                  0.023968       28                  0.119471         53                    0.668524          82                     0.370641            39
# 21   (FullBath, OverallQual, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)   (1stFlrSF, GrLivArea)                                                     0.149800      22                 0.694473        101                  0.176071       61                  0.275234         71                    0.275234          20                     0.512691            52
# 22   (1stFlrSF, GarageArea, GrLivArea, OverallQual)                               (TotalBsmtSF, TotRmsAbvGrd, FullBath, GarageCars)                         0.150927      23                 0.879829        110                  0.019110       26                  0.058782         38                    0.058782          5                      0.650147            65
# 23   (TotRmsAbvGrd, GrLivArea, OverallQual, GarageCars)                           (1stFlrSF, GarageArea, FullBath, TotalBsmtSF)                             0.173617      24                 0.596701        96                   0.012611       22                  0.023342         30                    0.762369          96                     0.449692            47
# 24   (GrLivArea, OverallQual, GarageCars, GarageArea, TotRmsAbvGrd)               (1stFlrSF, FullBath, TotalBsmtSF)                                         0.185686      25                 0.755497        106                  0.119471       53                  0.275758         74                    0.032284          2                      0.413686            44
# 25   (1stFlrSF, GrLivArea, OverallQual, GarageCars, TotalBsmtSF)                  (TotRmsAbvGrd, GarageArea, FullBath)                                      0.212912      26                 0.102081        45                   0.000460       4                   0.001077         7                     0.559305          71                     0.128996            10
# 26   (OverallQual, GarageArea, FullBath, GarageCars)                              (1stFlrSF, GrLivArea, TotRmsAbvGrd, TotalBsmtSF)                          0.226476      27                 0.058782        40                   0.545350       93                  0.879829         114                   0.405679          45                     0.939743            106
# 27   (GarageArea, GrLivArea, OverallQual, GarageCars)                             (1stFlrSF, TotRmsAbvGrd, FullBath, TotalBsmtSF)                           0.226476      28                 0.034294        34                   0.006502       18                  0.015564         26                    0.762369          95                     0.545350            55
# 28   (OverallQual, FullBath)                                                      (1stFlrSF, GrLivArea, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)  0.238646      29                 0.010025        18                   0.631171       98                  0.176071         61                    0.759982          88                     0.694473            68
# 29   (1stFlrSF, FullBath, OverallQual, GarageCars, TotalBsmtSF, TotRmsAbvGrd)     (GarageArea, GrLivArea)                                                   0.238646      30                 0.359397        78                   0.458123       89                  0.406975         84                    0.458123          56                     0.570465            59
# 30   (1stFlrSF, GrLivArea, OverallQual, GarageCars, TotalBsmtSF, GarageArea)      (TotRmsAbvGrd, FullBath)                                                  0.238646      31                 0.512691        85                   0.005968       16                  0.073553         45                    0.895830          109                    0.149800            13
# 31   (1stFlrSF, FullBath, OverallQual, GarageCars, TotRmsAbvGrd)                  (TotalBsmtSF, GarageArea, GrLivArea)                                      0.242908      32                 0.185686        59                   0.161125       58                  0.185686         64                    0.612840          75                     0.845687            91
# 32   (1stFlrSF, GrLivArea, OverallQual, GarageCars, TotRmsAbvGrd)                 (TotalBsmtSF, GarageArea, FullBath)                                       0.242908      33                 0.275758        71                   0.042960       39                  0.161125         60                    0.668524          83                     0.293271            33
# 33   (GrLivArea, OverallQual, GarageCars, TotalBsmtSF, GarageArea)                (1stFlrSF, TotRmsAbvGrd, FullBath)                                        0.242908      34                 0.023968        29                   0.001414       7                   0.005069         16                    0.413686          52                     0.149804            16
# 34   (1stFlrSF, OverallQual, FullBath, GarageCars)                                (TotalBsmtSF, GarageArea, GrLivArea, TotRmsAbvGrd)                        0.256839      35                 0.325751        74                   0.939743       117                 0.820596         111                   0.820596          102                    0.939743            102
# 35   (TotalBsmtSF, OverallQual, FullBath, GarageCars)                             (1stFlrSF, GarageArea, GrLivArea, TotRmsAbvGrd)                           0.256839      36                 0.001940        8                    0.289918       73                  0.130570         55                    0.650147          81                     0.820596            86
# 36   (OverallQual, TotRmsAbvGrd, FullBath, GarageCars)                            (1stFlrSF, GarageArea, GrLivArea, TotalBsmtSF)                            0.256839      37                 0.650147        100                  0.325751       79                  0.705457         105                   0.130570          13                     0.939743            107
# 37   (1stFlrSF, FullBath, GrLivArea, OverallQual, GarageCars, GarageArea)         (TotalBsmtSF, TotRmsAbvGrd)                                               0.275234      38                 0.275234        67                   0.315474       76                  0.359397         80                    0.512691          65                     0.275234            27
# 38   (TotalBsmtSF, OverallQual, FullBath)                                         (1stFlrSF, GrLivArea, GarageCars, GarageArea, TotRmsAbvGrd)               0.275758      39                 0.001846        7                    0.275758       71                  0.102081         49                    0.785257          98                     0.968950            112
# 39   (FullBath, OverallQual, GarageCars, TotalBsmtSF, GarageArea)                 (1stFlrSF, GrLivArea, TotRmsAbvGrd)                                       0.275758      40                 0.042960        38                   1.000000       119                 0.697092         103                   0.785257          101                    0.726095            79
# 40   (OverallQual, GarageArea, FullBath)                                          (1stFlrSF, GrLivArea, GarageCars, TotalBsmtSF, TotRmsAbvGrd)              0.311515      41                 0.073366        41                   0.640429       100                 0.755497         107                   0.330492          35                     0.845687            89
# 41   (FullBath, OverallQual, GarageCars, TotalBsmtSF, TotRmsAbvGrd)               (1stFlrSF, GarageArea, GrLivArea)                                         0.311515      42                 0.436275        83                   0.755497       106                 0.876270         113                   0.413686          51                     0.612840            62
# 42   (FullBath, OverallQual, TotalBsmtSF, GarageArea, TotRmsAbvGrd)               (1stFlrSF, GrLivArea, GarageCars)                                         0.311515      43                 0.815335        107                  0.242908       68                  0.275758         73                    0.459559          60                     0.559305            57
# 43   (1stFlrSF, FullBath, GrLivArea, OverallQual, GarageArea, TotRmsAbvGrd)       (TotalBsmtSF, GarageCars)                                                 0.315474      44                 0.205633        60                   0.895830       114                 0.965189         119                   0.759982          91                     0.275234            29
# 44   (1stFlrSF, OverallQual, FullBath)                                            (GrLivArea, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)            0.350201      45                 0.311515        72                   0.937947       115                 0.533417         91                    0.330492          34                     0.907038            96
# 45   (GrLivArea, OverallQual, GarageCars, TotalBsmtSF, TotRmsAbvGrd)              (1stFlrSF, GarageArea, FullBath)                                          0.350201      46                 0.391805        81                   0.002396       9                   0.008123         21                    0.413686          53                     0.110506            8
# 46   (1stFlrSF, FullBath, OverallQual, TotalBsmtSF, GarageArea, TotRmsAbvGrd)     (GrLivArea, GarageCars)                                                   0.359397      47                 0.106351        47                   0.088737       48                  0.073553         44                    0.631171          80                     0.458123            49
# 47   (TotalBsmtSF, OverallQual, GarageArea, FullBath)                             (1stFlrSF, GrLivArea, TotRmsAbvGrd, GarageCars)                           0.364346      48                 0.034294        33                   0.879829       113                 0.496292         89                    0.325751          33                     0.820596            87
# 48   (TotRmsAbvGrd, OverallQual, GarageArea, FullBath)                            (1stFlrSF, TotalBsmtSF, GrLivArea, GarageCars)                            0.364346      49                 0.545350        91                   0.096304       51                  0.150927         59                    0.289918          23                     0.879829            95
# 49   (TotalBsmtSF, GarageArea, OverallQual)                                       (1stFlrSF, FullBath, GrLivArea, GarageCars, TotRmsAbvGrd)                 0.391805      50                 0.212912        62                   0.139101       55                  0.139101         56                    0.612840          74                     0.845687            90
# 50   (1stFlrSF, FullBath, OverallQual, GarageCars, TotalBsmtSF)                   (GarageArea, GrLivArea, TotRmsAbvGrd)                                     0.391805      51                 0.161125        56                   0.585788       96                  0.533417         92                    0.370641          41                     0.726095            76
# 51   (FullBath, OverallQual, GarageCars, GarageArea, TotRmsAbvGrd)                (1stFlrSF, GrLivArea, TotalBsmtSF)                                        0.391805      52                 0.585788        94                   0.051625       43                  0.086768         47                    0.370641          42                     0.785257            83
# 52   (1stFlrSF, OverallQual, GarageArea, FullBath)                                (TotalBsmtSF, GrLivArea, TotRmsAbvGrd, GarageCars)                        0.405679      53                 0.939743        114                  0.325751       78                  0.496292         88                    0.762369          92                     0.939743            103
# 53   (1stFlrSF, OverallQual, TotRmsAbvGrd, FullBath)                              (TotalBsmtSF, GarageArea, GrLivArea, GarageCars)                          0.405679      54                 0.150927        54                   0.198765       62                  0.364346         81                    0.289918          22                     1.000000            118
# 54   (1stFlrSF, FullBath, GrLivArea, OverallQual, TotalBsmtSF, TotRmsAbvGrd)      (GarageArea, GarageCars)                                                  0.406975      55                 0.965189        118                  0.176071       60                  0.088737         48                    0.759982          90                     0.149800            12
# 55   (OverallQual, TotRmsAbvGrd, FullBath)                                        (1stFlrSF, GrLivArea, GarageCars, TotalBsmtSF, GarageArea)                0.436275      56                 0.697092        103                  0.436275       85                  0.937947         116                   0.293271          24                     0.968950            113
# 56   (1stFlrSF, FullBath, OverallQual, TotalBsmtSF, GarageArea)                   (GrLivArea, TotRmsAbvGrd, GarageCars)                                     0.436275      57                 0.585788        93                   0.697092       104                 0.815335         110                   0.413686          48                     0.726095            77
# 57   (1stFlrSF, FullBath, OverallQual, GarageArea, TotRmsAbvGrd)                  (TotalBsmtSF, GrLivArea, GarageCars)                                      0.436275      58                 0.023968        28                   0.035558       35                  0.035558         35                    0.968950          118                    0.726095            78
# 58   (1stFlrSF, FullBath, OverallQual, GarageCars, TotalBsmtSF, GarageArea)       (GrLivArea, TotRmsAbvGrd)                                                 0.458123      59                 0.570465        92                   0.694473       101                 0.570465         94                    0.315474          29                     0.631171            64
# 59   (1stFlrSF, GrLivArea, OverallQual, GarageCars, TotalBsmtSF, TotRmsAbvGrd)    (GarageArea, FullBath)                                                    0.458123      60                 0.512691        86                   0.010025       20                  0.106351         50                    0.895830          110                    0.106351            4
# 60   (GrLivArea, OverallQual, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)  (1stFlrSF, FullBath)                                                      0.458123      61                 0.895830        111                  0.040243       37                  0.176071         62                    0.275234          21                     0.176071            20
# 61   (1stFlrSF, OverallQual, TotalBsmtSF)                                         (FullBath, GrLivArea, GarageCars, GarageArea, TotRmsAbvGrd)               0.483522      62                 0.697092        102                  0.042960       38                  0.061707         41                    0.370641          39                     0.785257            82
# 62   (TotalBsmtSF, OverallQual, GarageCars)                                       (1stFlrSF, FullBath, GrLivArea, GarageArea, TotRmsAbvGrd)                 0.483522      63                 0.015807        20                   0.029273       31                  0.023968         31                    0.968950          117                    0.726095            73
# 63   (1stFlrSF, OverallQual, GarageCars, GarageArea, TotRmsAbvGrd)                (TotalBsmtSF, GrLivArea, FullBath)                                        0.483522      64                 0.002396        9                    0.350201       80                  0.119471         54                    0.726095          87                     0.968950            117
# 64   (1stFlrSF, OverallQual, FullBath, TotalBsmtSF)                               (GarageArea, GrLivArea, TotRmsAbvGrd, GarageCars)                         0.496292      65                 0.173617        57                   0.496292       91                  0.289918         75                    0.939743          115                    0.762369            80
# 65   (1stFlrSF, TotRmsAbvGrd, OverallQual, TotalBsmtSF)                           (GarageArea, GrLivArea, FullBath, GarageCars)                             0.496292      66                 0.058782        39                   0.449692       87                  0.762369         109                   0.405679          44                     0.939743            105
# 66   (TotRmsAbvGrd, GarageArea, OverallQual)                                      (1stFlrSF, FullBath, GrLivArea, GarageCars, TotalBsmtSF)                  0.533417      67                 0.139101        53                   0.697092       103                 0.585788         96                    0.508148          61                     0.726095            75
# 67   (1stFlrSF, FullBath, GrLivArea, OverallQual, GarageArea)                     (TotalBsmtSF, TotRmsAbvGrd, GarageCars)                                   0.533417      68                 0.275758        69                   0.242908       67                  0.139101         57                    0.459559          59                     0.370641            37
# 68   (1stFlrSF, OverallQual, TotalBsmtSF, GarageArea, TotRmsAbvGrd)               (GrLivArea, FullBath, GarageCars)                                         0.533417      69                 0.012731        19                   0.755497       105                 0.311515         77                    0.845687          107                    0.845687            93
# 69   (1stFlrSF, TotalBsmtSF, OverallQual, GarageCars)                             (TotRmsAbvGrd, GarageArea, GrLivArea, FullBath)                           0.545350      70                 0.650147        99                   0.082099       46                  0.112411         51                    0.762369          93                     0.879829            94
# 70   (1stFlrSF, GarageArea, OverallQual, TotalBsmtSF)                             (TotRmsAbvGrd, GrLivArea, FullBath, GarageCars)                           0.545350      71                 0.596701        95                   0.289918       72                  0.596701         97                    0.449692          54                     0.939743            104
# 71   (TotalBsmtSF, OverallQual, TotRmsAbvGrd, FullBath)                           (1stFlrSF, GarageArea, GrLivArea, GarageCars)                             0.545350      72                 0.405679        82                   0.820596       109                 0.650147         100                   0.096304          10                     0.705457            71
# 72   (TotalBsmtSF, OverallQual)                                                   (1stFlrSF, FullBath, GrLivArea, GarageCars, GarageArea, TotRmsAbvGrd)     0.570465      73                 0.020717        25                   0.032473       33                  0.026026         33                    0.315474          28                     0.406975            41
# 73   (GarageArea, OverallQual)                                                    (1stFlrSF, FullBath, GrLivArea, GarageCars, TotalBsmtSF, TotRmsAbvGrd)    0.570465      74                 0.359397        77                   0.406975       84                  0.359397         79                    0.458123          55                     0.570465            58
# 74   (TotRmsAbvGrd, OverallQual)                                                  (1stFlrSF, FullBath, GrLivArea, GarageCars, TotalBsmtSF, GarageArea)      0.570465      75                 0.512691        84                   0.570465       94                  0.512691         90                    0.406975          46                     0.631171            63
# 75   (1stFlrSF, FullBath, GrLivArea, OverallQual, TotalBsmtSF, GarageArea)        (TotRmsAbvGrd, GarageCars)                                                0.570465      76                 0.106351        46                   0.106351       52                  0.060563         40                    0.759982          89                     0.149800            11
# 76   (OverallQual, GrLivArea, FullBath)                                           (1stFlrSF, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)             0.585788      77                 0.000614        3                    0.019517       27                  0.001846         9                     0.459559          58                     0.968950            111
# 77   (FullBath, GrLivArea, OverallQual, TotalBsmtSF, TotRmsAbvGrd)                (1stFlrSF, GarageArea, GarageCars)                                        0.585788      78                 0.073366        43                   0.051625       42                  0.008123         20                    0.612840          77                     0.110506            7
# 78   (TotRmsAbvGrd, 1stFlrSF, GarageArea, OverallQual)                            (TotalBsmtSF, GrLivArea, FullBath, GarageCars)                            0.596701      79                 0.002497        11                   0.364346       81                  0.150927         58                    0.069642          6                      0.820596            85
# 79   (TotRmsAbvGrd, GarageArea, OverallQual, GarageCars)                          (1stFlrSF, GrLivArea, FullBath, TotalBsmtSF)                              0.596701      80                 0.150927        55                   0.596701       97                  0.325751         78                    0.364346          38                     0.762369            81
# 80   (TotRmsAbvGrd, TotalBsmtSF, GarageArea, OverallQual)                         (1stFlrSF, GrLivArea, FullBath, GarageCars)                               0.596701      81                 0.256839        66                   0.820596       110                 0.939743         118                   0.198765          16                     0.939743            109
# 81   (1stFlrSF, FullBath, GrLivArea, OverallQual, GarageCars, TotRmsAbvGrd)       (TotalBsmtSF, GarageArea)                                                 0.631171      82                 0.965189        117                  0.458123       88                  0.458123         86                    0.512691          66                     0.275234            28
# 82   (FullBath, GrLivArea, OverallQual, GarageCars, TotalBsmtSF, TotRmsAbvGrd)    (1stFlrSF, GarageArea)                                                    0.631171      83                 0.106351        48                   0.073553       45                  0.020717         28                    0.895830          112                    0.088737            2
# 83   (TotRmsAbvGrd, OverallQual, GarageCars)                                      (1stFlrSF, FullBath, GrLivArea, TotalBsmtSF, GarageArea)                  0.640429      84                 0.533417        88                   0.585788       95                  0.755497         108                   0.726095          86                     0.726095            74
# 84   (1stFlrSF, FullBath, OverallQual, GarageCars, GarageArea)                    (TotalBsmtSF, GrLivArea, TotRmsAbvGrd)                                    0.640429      85                 0.937947        113                  0.311515       75                  0.275758         72                    0.559305          70                     0.907038            100
# 85   (TotalBsmtSF, GarageArea, OverallQual, GarageCars)                           (TotRmsAbvGrd, 1stFlrSF, GrLivArea, FullBath)                             0.650147      86                 0.173617        58                   0.173617       59                  0.289918         76                    0.939743          116                    1.000000            119
# 86   (1stFlrSF, OverallQual)                                                      (FullBath, GrLivArea, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)  0.694473      87                 0.965189        116                  0.149800       57                  0.238646         66                    0.275234          19                     0.512691            51
# 87   (OverallQual, GarageCars)                                                    (1stFlrSF, FullBath, GrLivArea, TotalBsmtSF, GarageArea, TotRmsAbvGrd)    0.694473      88                 0.088737        44                   0.073553       44                  0.060563         39                    0.631171          79                     0.458123            48
# 88   (1stFlrSF, TotRmsAbvGrd, OverallQual)                                        (FullBath, GrLivArea, GarageCars, TotalBsmtSF, GarageArea)                0.697092      89                 0.023968        27                   0.876270       112                 0.755497         106                   0.370641          40                     0.726095            72
# 89   (TotalBsmtSF, TotRmsAbvGrd, OverallQual)                                     (1stFlrSF, FullBath, GrLivArea, GarageCars, GarageArea)                   0.697092      90                 0.937947        112                  0.242908       66                  0.212912         65                    0.559305          68                     0.907038            99
# 90   (1stFlrSF, FullBath, OverallQual, TotalBsmtSF, TotRmsAbvGrd)                 (GarageArea, GrLivArea, GarageCars)                                       0.697092      91                 0.275758        70                   0.436275       86                  0.640429         98                    0.785257          100                    0.668524            67
# 91   (1stFlrSF, OverallQual, GrLivArea, FullBath)                                 (TotalBsmtSF, GarageArea, TotRmsAbvGrd, GarageCars)                       0.705457      92                 0.034294        32                   0.034294       34                  0.008151         22                    1.000000          119                    0.449692            45
# 92   (1stFlrSF, FullBath, GrLivArea, OverallQual, TotalBsmtSF)                    (GarageArea, TotRmsAbvGrd, GarageCars)                                    0.755497      93                 0.019517        24                   0.008123       19                  0.001846         10                    0.559305          69                     0.110506            6
# 93   (1stFlrSF, FullBath, GrLivArea, OverallQual, TotRmsAbvGrd)                   (TotalBsmtSF, GarageArea, GarageCars)                                     0.755497      94                 0.755497        105                  0.311515       74                  0.185686         63                    0.508148          62                     0.370641            38
# 94   (1stFlrSF, OverallQual, GarageCars, TotalBsmtSF, GarageArea)                 (TotRmsAbvGrd, GrLivArea, FullBath)                                       0.755497      95                 0.640429        98                   0.391805       83                  0.937947         117                   0.907038          114                    0.968950            116
# 95   (FullBath, GrLivArea, OverallQual, GarageCars, TotRmsAbvGrd)                 (1stFlrSF, GarageArea, TotalBsmtSF)                                       0.755497      96                 0.119471        50                   0.212912       65                  0.073366         43                    0.508148          64                     0.258972            26
# 96   (1stFlrSF, FullBath, GrLivArea, OverallQual, GarageCars, TotalBsmtSF)        (GarageArea, TotRmsAbvGrd)                                                0.759982      97                 0.020717        26                   0.012858       23                  0.007762         18                    0.359397          36                     0.088737            1
# 97   (1stFlrSF, FullBath, OverallQual, GarageCars, GarageArea, TotRmsAbvGrd)      (TotalBsmtSF, GrLivArea)                                                  0.759982      98                 0.032473        31                   0.040243       36                  0.040243         36                    0.315474          30                     0.406975            42
# 98   (FullBath, GrLivArea, OverallQual, TotalBsmtSF, GarageArea, TotRmsAbvGrd)    (1stFlrSF, GarageCars)                                                    0.759982      99                 0.315474        73                   0.315474       77                  0.275234         70                    0.359397          37                     0.106351            5
# 99   (TotalBsmtSF, OverallQual, GrLivArea, FullBath)                              (1stFlrSF, GarageArea, TotRmsAbvGrd, GarageCars)                          0.762369      100                0.000157        1                    0.003197       14                  0.000381         2                     0.596701          73                     0.256839            22
# 100  (TotRmsAbvGrd, OverallQual, GrLivArea, FullBath)                             (1stFlrSF, TotalBsmtSF, GarageArea, GarageCars)                           0.762369      101                0.130570        52                   0.130570       54                  0.023342         29                    0.762369          94                     0.449692            46
# 101  (TotalBsmtSF, TotRmsAbvGrd, OverallQual, GarageCars)                         (1stFlrSF, GarageArea, GrLivArea, FullBath)                               0.762369      102                0.939743        115                  0.256839       69                  0.405679         83                    0.762369          97                     0.939743            108
# 102  (1stFlrSF, OverallQual, GarageCars)                                          (FullBath, GrLivArea, TotalBsmtSF, GarageArea, TotRmsAbvGrd)              0.815335      103                0.876270        108                  0.212912       63                  0.242908         68                    0.459559          57                     0.559305            56
# 103  (FullBath, GrLivArea, OverallQual, TotalBsmtSF, GarageArea)                  (1stFlrSF, TotRmsAbvGrd, GarageCars)                                      0.815335      104                0.002396        10                   0.029273       32                  0.005069         15                    0.612840          76                     0.149804            15
# 104  (1stFlrSF, TotRmsAbvGrd, OverallQual, GarageCars)                            (TotalBsmtSF, GarageArea, GrLivArea, FullBath)                            0.820596      105                0.019110        22                   1.000000       118                 0.545350         93                    0.325751          32                     0.820596            84
# 105  (OverallQual, GrLivArea, FullBath, GarageArea)                               (1stFlrSF, TotalBsmtSF, TotRmsAbvGrd, GarageCars)                         0.820596      106                0.005159        12                   0.096304       50                  0.015564         25                    0.130570          12                     0.545350            54
# 106  (1stFlrSF, GarageArea, OverallQual)                                          (FullBath, GrLivArea, GarageCars, TotalBsmtSF, TotRmsAbvGrd)              0.876270      107                0.350201        76                   0.697092       102                 0.937947         115                   0.413686          47                     0.612840            61
# 107  (1stFlrSF, OverallQual, GarageCars, TotalBsmtSF, TotRmsAbvGrd)               (GarageArea, GrLivArea, FullBath)                                         0.876270      108                0.073366        42                   0.533417       92                  0.876270         112                   0.845687          106                    0.845687            92
# 108  (FullBath, GrLivArea, OverallQual, GarageCars, GarageArea)                   (1stFlrSF, TotRmsAbvGrd, TotalBsmtSF)                                     0.876270      109                0.006435        14                   0.139101       56                  0.051625         37                    0.508148          63                     0.330492            36
# 109  (FullBath, GrLivArea, OverallQual, GarageArea, TotRmsAbvGrd)                 (1stFlrSF, TotalBsmtSF, GarageCars)                                       0.876270      110                0.533417        90                   0.483522       90                  0.391805         82                    0.559305          72                     0.293271            34
# 110  (1stFlrSF, GarageArea, OverallQual, GarageCars)                              (TotRmsAbvGrd, TotalBsmtSF, GrLivArea, FullBath)                          0.879829      111                0.325751        75                   0.762369       108                 0.705457         104                   0.705457          85                     0.705457            70
# 111  (OverallQual, GrLivArea, FullBath, GarageCars)                               (1stFlrSF, GarageArea, TotRmsAbvGrd, TotalBsmtSF)                         0.879829      112                0.000670        4                    0.015564       24                  0.001940         11                    0.130570          11                     0.405679            40
# 112  (FullBath, GrLivArea, OverallQual, GarageCars, TotalBsmtSF, GarageArea)      (1stFlrSF, TotRmsAbvGrd)                                                  0.895830      113                0.007762        16                   0.049535       40                  0.012858         24                    0.895830          111                    0.126630            9
# 113  (GarageArea, OverallQual, GarageCars)                                        (1stFlrSF, FullBath, GrLivArea, TotalBsmtSF, TotRmsAbvGrd)                0.937947      114                0.275758        68                   0.391805       82                  0.585788         95                    0.785257          99                     0.668524            66
# 114  (1stFlrSF, FullBath, GrLivArea, OverallQual, GarageCars)                     (TotalBsmtSF, GarageArea, TotRmsAbvGrd)                                   0.937947      115                0.035558        35                   0.051625       41                  0.023968         32                    0.094175          9                      0.258972            25
# 115  (OverallQual, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)             (1stFlrSF, GrLivArea, FullBath)                                           0.937947      116                0.242908        65                   0.937947       116                 0.640429         99                    0.293271          27                     0.907038            101
# 116  (1stFlrSF, OverallQual, GarageCars, TotalBsmtSF, GarageArea, TotRmsAbvGrd)   (GrLivArea, FullBath)                                                     0.965189      117                0.016377        21                   0.759982       107                 0.238646         67                    0.827259          105                    0.694473            69
# 117  (FullBath, GrLivArea, OverallQual, GarageCars, GarageArea, TotRmsAbvGrd)     (1stFlrSF, TotalBsmtSF)                                                   0.965189      118                0.512691        87                   0.827259       111                 0.694473         102                   0.315474          31                     0.275234            31
# 118  (FullBath, GrLivArea, OverallQual, GarageCars, TotalBsmtSF)                  (1stFlrSF, GarageArea, TotRmsAbvGrd)                                      1.000000      119                0.000460        2                    0.003093       13                  0.000460         4                     0.293271          26                     0.094175            3
