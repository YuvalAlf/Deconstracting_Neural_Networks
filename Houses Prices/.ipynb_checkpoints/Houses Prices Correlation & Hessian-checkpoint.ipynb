# %%
import numpy as np
import seaborn as sns
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import tree
from keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.neighbors import KNeighborsRegressor
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping
from keras.models import load_model
from numpy.random import seed
from statsmodels.stats.multitest import multipletests
from scipy.stats import ranksums
from more_itertools import powerset

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'    

sns.set()
warnings.filterwarnings('ignore')
random_seed = 10000
seed(random_seed)
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('houses_dataset.csv', index_col = 'Id')
df = df._get_numeric_data()
df = df.dropna(axis='columns')
df_rows = df.shape[0]
zero_precents = df.astype(bool).apply(lambda x: ~x).sum(axis = 0) / df_rows
zero_columns_labels = list(zero_precents[zero_precents > 0.333].index)
df = df.drop(zero_columns_labels, axis = 1)
df = df.drop(['KitchenAbvGr'], axis = 1)
df.head(10)
# Out:
#     MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1           60     8450            7            5       2003          2003
# 2           20     9600            6            8       1976          1976
# 3           60    11250            7            5       2001          2002
# 4           70     9550            7            5       1915          1970
# 5           60    14260            8            5       2000          2000
# 6           50    14115            5            5       1993          1995
# 7           20    10084            8            5       2004          2005
# 8           60    10382            7            6       1973          1973
# 9           50     6120            7            5       1931          1950
# 10         190     7420            5            6       1939          1950
#
#     BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  \
# Id
# 1          706        150          856       856       1710         2
# 2          978        284         1262      1262       1262         2
# 3          486        434          920       920       1786         2
# 4          216        540          756       961       1717         1
# 5          655        490         1145      1145       2198         2
# 6          732         64          796       796       1362         1
# 7         1369        317         1686      1694       1694         2
# 8          859        216         1107      1107       2090         2
# 9            0        952          952      1022       1774         2
# 10         851        140          991      1077       1077         1
#
#     BedroomAbvGr  TotRmsAbvGrd  GarageCars  GarageArea  MoSold  YrSold  \
# Id
# 1              3             8           2         548       2    2008
# 2              3             6           2         460       5    2007
# 3              3             6           2         608       9    2008
# 4              3             7           3         642       2    2006
# 5              4             9           3         836      12    2008
# 6              1             5           2         480      10    2009
# 7              3             7           2         636       8    2007
# 8              3             7           2         484      11    2009
# 9              2             8           2         468       4    2008
# 10             2             5           1         205       1    2008
#
#     SalePrice
# Id
# 1      208500
# 2      181500
# 3      223500
# 4      140000
# 5      250000
# 6      143000
# 7      307000
# 8      200000
# 9      129900
# 10     118000

# %% [markdown]
# ## Correlation to Sale-Price

# %%
correlation = df.corr()['SalePrice'].sort_values()
dd = pd.DataFrame(correlation)
chart = sns.barplot(correlation.index, correlation.values, palette="Blues_d")
_ = chart.set_xticklabels(chart.get_xticklabels(), rotation=90)

# %%
top_8_cats = abs(df.corr())['SalePrice'].sort_values(ascending=False)[1:(1+8)]
for cat in top_8_cats.index:
    print(cat)
data = df[list(top_8_cats.index) + ["SalePrice"]]
# Out:
# OverallQual
# GrLivArea
# GarageCars
# GarageArea
# TotalBsmtSF
# 1stFlrSF
# FullBath
# TotRmsAbvGrd

# %% [markdown]
# ## Visualization

# %%
_ = sns.pairplot(data=data, y_vars=['SalePrice'], x_vars=data.columns, kind="reg", diag_kind="kde", plot_kws={'line_kws':{'color':'purple'}, 'scatter_kws': {'alpha': 0.2}})

# %% [markdown]
# # Correlation Heatmap

# %%
_ = sns.heatmap(data.corr(), cmap="BrBG", linewidths = 1, vmin = -1, vmax = 1, annot = True)

# %% [markdown]
# # Neural Network Training

# %%
test_precent = 0.15
train_precent = 1.0 - test_precent
train_data = data.sample(frac=train_precent, random_state=random_seed)
test_data = data.drop(train_data.index)

# %%
train_stats = train_data.describe().T
def normalize(x):
    result = x.copy()
    for feature_name in x.columns:
        average = x[feature_name].mean()
        std = x[feature_name].std()
        result[feature_name] = (x[feature_name] - average) / std
    return result
normalized_train_data = normalize(train_data)
normalized_test_data = normalize(test_data)
normalized_train_data.head()
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# Id
# 1356     0.643370   0.746126    0.291487    0.043976    -1.103240  0.130061
# 1141    -0.801738  -1.073912    0.291487    1.708025    -0.254483 -0.554142
# 491     -0.801738  -0.412080   -1.063329   -0.667841    -1.783135 -1.405594
# 449     -0.079184  -0.276705   -1.063329   -1.318376    -0.636646 -0.990004
# 358     -0.801738  -0.716673    0.291487    0.237251     0.167674 -0.072666
#
#       FullBath  TotRmsAbvGrd  SalePrice
# Id
# 1356  2.583995      0.903746  -0.150385
# 1141 -1.041486     -1.559842  -0.530158
# 491  -1.041486     -1.559842  -0.824177
# 449   0.771255      0.287849  -0.769048
# 358  -1.041486     -0.328048  -0.591412

# %%
train_x = normalized_train_data.drop('SalePrice', axis = 1)
train_y = normalized_train_data['SalePrice']
test_x = normalized_test_data.drop('SalePrice', axis = 1)
test_y = normalized_test_data['SalePrice']

# %%
def build_fully_NN_model(train):
    input_layer    = Input(shape=(train.shape[1],))
    hidden_layer_1 = Dense(8, activation=tf.nn.relu)(input_layer)
    hidden_layer_2 = Dense(8, activation=tf.nn.relu)(hidden_layer_1)
    output_layer   = Dense(1)(hidden_layer_2)
   
    model = Model(input=[input_layer], output=[output_layer])
    last_layer_model = Model(input=[input_layer], output=[hidden_layer_2])
    
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    

    return model, last_layer_model

# %%
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

def trainModel(model, X, Y):
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=50)
    mc = ModelCheckpoint('best_nn_model.nn', monitor='val_loss', mode='min', verbose=0, save_best_only=True)
    history = model.fit(X, Y, epochs=400, validation_split = 0.33, verbose=0, callbacks=[PrintDot(), es, mc])
    model = load_model('best_nn_model.nn')
    return history, model

# %%
fully_NN_model, last_layer_NN_model = build_fully_NN_model(train_x)
fully_NN_history, fully_NN_model = trainModel(fully_NN_model, train_x, train_y)
# Out:
# ....................................................................................................
# ............................................................

# %%
def plot_history(history):    
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch 
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mean_squared_error'], label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'], label = 'Validation Error')
  #plt.ylim([0,1000])
  plt.legend()
  plt.show()

plot_history(fully_NN_history)

# %% [markdown]
# ## Test Set

# %%
def show_test_predictions(name, model, test_X, test_Y):
    loss, mse = model.evaluate(test_X, test_Y, verbose=0)
    print(name + ' MSE = ' + str(mse))
    test_predictions = model.predict(test_X).flatten()

    plt.scatter(test_Y, test_predictions, alpha = 0.4, color = 'salmon')
    plt.xlabel('True Values [MPG]')
    plt.ylabel('Predictions [MPG]')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim([-10,10])
    plt.ylim([-10,10])
    _ = plt.plot([-5, 5], [-5, 5], color = 'black')
show_test_predictions('Test Set', fully_NN_model, test_x, test_y)
# Out:
# Test Set MSE = 0.1427006721496582

# %% [markdown]
# ## Train Set

# %%
def show_test_predictions(name, model, testX, testY):
    loss, mse = model.evaluate(testX, testY, verbose=0)
    print(name + ' MSE = ' + str(mse))
    test_predictions = model.predict(testX).flatten()

    plt.scatter(testY, test_predictions, alpha = 0.15, color = 'purple')
    plt.xlabel('True Values [MPG]')
    plt.ylabel('Predictions [MPG]')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim([-10,10])
    plt.ylim([-10,10])
    _ = plt.plot([-5, 5], [-5, 5], color = 'black')
show_test_predictions('Train Set', fully_NN_model, train_x, train_y)
# Out:
# Train Set MSE = 0.15851016342639923

# %%
def evaluate(model, input_data):
    return model.predict(np.array([input_data]))[0][0]

def copy_and_add(data_list, dim_1, amount_1, dim_2, amount_2):
    data_list = data_list.copy()
    data_list[dim_1] += amount_1
    data_list[dim_2] += amount_2
    return data_list

def get_second_derivative(model, input_data, dim_1, dim_2):
    eps = 0.05
    f_pp = evaluate(model, copy_and_add(input_data, dim_1, eps, dim_2, eps))
    f_mm = evaluate(model, copy_and_add(input_data, dim_1, -eps, dim_2, -eps))
    f_mp = evaluate(model, copy_and_add(input_data, dim_1, -eps, dim_2, eps))
    f_pm = evaluate(model, copy_and_add(input_data, dim_1, eps, dim_2, -eps))
    return (f_pp - f_mm) / (4*eps*eps)
    #return (f_pp + f_mm - f_mp - f_pm) / (4*eps*eps)

def input_data_options(list_data):
    if (len(list_data) == 8):
        yield list_data
    else:
        for option in [0.3, 0.7]:
            list_data.append(option)
            for inner_res in input_data_options(list_data):
                yield inner_res
            list_data.pop()
hessian = np.zeros((8,8))
abs_hessian = np.zeros((8,8))
i = 0
for input_data in input_data_options([]):
    i += 1
    if (i % 100 == 0):
        print('.', end='')
    for dim_1 in range(8):
        for dim_2 in range(8):
            div = get_second_derivative(fully_NN_model, input_data, dim_1, dim_2)
            hessian[dim_1, dim_2] += div
            abs_hessian[dim_1, dim_2] += abs(div)
input_amount = sum(1 for _ in input_data_options([]))
hessian /= input_amount
abs_hessian /= input_amount
# Out:
# ..

# %% [markdown]
# # Average of second derivatives ('Hessian')

# %%
names = data.corr().columns[:8]
hessian_df = pd.DataFrame(hessian, index = names, columns=names)
_ = sns.heatmap(hessian_df, cmap="BrBG", linewidths = 1, vmin = -2, vmax = 15, annot = True)

# %% [markdown]
# # Average of absoulte second derivatives

# %%
names = data.corr().columns[:8]
abs_hessian_df = pd.DataFrame(abs_hessian, index = names, columns=names)
_ = sns.heatmap(abs_hessian_df, cmap="BrBG", linewidths = 1, vmin = 2, vmax = 15, annot = True)

# %% [markdown]
# # Prametric-Rank-Sum

# %%
def perform_parametric_rank_sum(hess):
    n_inputs = hess.shape[0]
    inputs = set(hess.columns)
    partitions = [(set(partition), inputs - set(partition))
                      for partition in powerset(inputs)
                      if len(partition) >=2 and len(partition) <= n_inputs - 2 and 'OverallQual' in partition]
    
    def extract_triangle(cols):
        data = hess.loc[cols, cols]
        data = data.where(np.triu(np.ones(data.shape)).astype(bool)).stack().to_numpy()
        return data
    
    triangular_samples = [((group1, extract_triangle(group1)), (group2, extract_triangle(group2)))
                          for group1, group2 in partitions]
    rank_sum_pvalues = [(g1, g2, ranksums(x=g1_data, y=g2_data).pvalue)
                        for ((g1, g1_data), (g2, g2_data)) in triangular_samples]
    pvalues = list(map(lambda c: c[2], rank_sum_pvalues))
    alpha = 0.05
    rank_sum_pvalues_adj = multipletests(pvals=pvalues, is_sorted = False, method = 'holm-sidak', alpha = alpha)[1]
    results = [(g1, g2, orig_pval, adj_pval)
               for ((g1, g2, orig_pval), adj_pval) in zip(rank_sum_pvalues, rank_sum_pvalues_adj)]
    sorted_results = sorted(results, key = lambda x: x[2])
    
    return pd.DataFrame(sorted_results, columns=['group1', 'group2', 'pvalue', 'adjusted pvalue'])

# %% [markdown]
# # Prametric-Rank-Sum Absolute Hessian

# %%
abs_hess_data_frame = perform_parametric_rank_sum(abs_hessian_df)
abs_hess_data_frame.head(10)
# Out:
#                                               group1  \
# 0  {OverallQual, GarageCars, GrLivArea, TotalBsmtSF}
# 1    {OverallQual, FullBath, GrLivArea, TotalBsmtSF}
# 2              {OverallQual, GrLivArea, TotalBsmtSF}
# 3  {OverallQual, GarageCars, FullBath, TotalBsmtS...
# 4    {OverallQual, 1stFlrSF, GrLivArea, TotalBsmtSF}
# 5  {OverallQual, 1stFlrSF, FullBath, TotalBsmtSF,...
# 6               {OverallQual, GarageCars, GrLivArea}
# 7  {OverallQual, GarageCars, 1stFlrSF, TotalBsmtS...
# 8                 {OverallQual, FullBath, GrLivArea}
# 9  {OverallQual, GarageArea, GrLivArea, TotalBsmtSF}
#
#                                               group2    pvalue  \
# 0     {TotRmsAbvGrd, FullBath, 1stFlrSF, GarageArea}  0.000212
# 1   {GarageCars, GarageArea, 1stFlrSF, TotRmsAbvGrd}  0.000285
# 2  {GarageCars, 1stFlrSF, FullBath, GarageArea, T...  0.000460
# 3               {GarageArea, 1stFlrSF, TotRmsAbvGrd}  0.000460
# 4   {GarageCars, FullBath, GarageArea, TotRmsAbvGrd}  0.000507
# 5             {GarageCars, GarageArea, TotRmsAbvGrd}  0.001077
# 6  {1stFlrSF, FullBath, TotalBsmtSF, GarageArea, ...  0.001414
# 7               {FullBath, GarageArea, TotRmsAbvGrd}  0.001414
# 8  {GarageCars, 1stFlrSF, TotalBsmtSF, GarageArea...  0.001846
# 9     {GarageCars, FullBath, 1stFlrSF, TotRmsAbvGrd}  0.001940
#
#    adjusted pvalue
# 0         0.024936
# 1         0.033089
# 2         0.052368
# 3         0.052368
# 4         0.056602
# 5         0.115561
# 6         0.147735
# 7         0.147735
# 8         0.185405
# 9         0.192310

# %% [markdown]
# # Prametric-Rank-Sum Hessian

# %%
hess_data_frame = perform_parametric_rank_sum(hessian_df)
hess_data_frame['absolute hessian pvalue index'] = \
    hess_data_frame['group1'].apply(lambda g: abs_hess_data_frame['group1'][abs_hess_data_frame['group1'] == g].index.tolist()[0])
cols = hess_data_frame.columns.tolist()
cols = [cols[-1]]+cols[:-1]
print(cols)
hess_data_frame = hess_data_frame.reindex(columns=cols)

hess_data_frame.head(30)
# Out:
# ['absolute hessian pvalue index', 'group1', 'group2', 'pvalue', 'adjusted pvalue']
#     absolute hessian pvalue index  \
# 0                               0
# 1                               4
# 2                               2
# 3                               7
# 4                               6
# 5                               9
# 6                              19
# 7                              13
# 8                               3
# 9                              15
# 10                              1
# 11                             20
# 12                             27
# 13                             10
# 14                             16
# 15                             46
# 16                              5
# 17                             33
# 18                             29
# 19                             17
# 20                             21
# 21                             11
# 22                             52
# 23                             35
# 24                              8
# 25                             42
# 26                             26
# 27                             61
# 28                             12
# 29                             18
#
#                                                group1  \
# 0   {OverallQual, GarageCars, GrLivArea, TotalBsmtSF}
# 1     {OverallQual, 1stFlrSF, GrLivArea, TotalBsmtSF}
# 2               {OverallQual, GrLivArea, TotalBsmtSF}
# 3   {OverallQual, GarageCars, 1stFlrSF, TotalBsmtS...
# 4                {OverallQual, GarageCars, GrLivArea}
# 5   {OverallQual, GarageArea, GrLivArea, TotalBsmtSF}
# 6   {OverallQual, GarageCars, TotalBsmtSF, GarageA...
# 7                  {OverallQual, 1stFlrSF, GrLivArea}
# 8   {OverallQual, GarageCars, FullBath, TotalBsmtS...
# 9      {OverallQual, 1stFlrSF, GarageCars, GrLivArea}
# 10    {OverallQual, FullBath, GrLivArea, TotalBsmtSF}
# 11  {OverallQual, GarageCars, TotalBsmtSF, TotRmsA...
# 12  {OverallQual, 1stFlrSF, TotalBsmtSF, GarageAre...
# 13  {OverallQual, TotRmsAbvGrd, GrLivArea, TotalBs...
# 14                           {OverallQual, GrLivArea}
# 15  {OverallQual, GarageCars, 1stFlrSF, TotalBsmtS...
# 16  {OverallQual, 1stFlrSF, FullBath, TotalBsmtSF,...
# 17   {OverallQual, GarageArea, GarageCars, GrLivArea}
# 18  {OverallQual, 1stFlrSF, TotalBsmtSF, TotRmsAbv...
# 19  {OverallQual, GarageCars, 1stFlrSF, FullBath, ...
# 20               {OverallQual, GarageArea, GrLivArea}
# 21     {OverallQual, FullBath, GarageCars, GrLivArea}
# 22  {OverallQual, GarageCars, 1stFlrSF, TotalBsmtS...
# 23  {OverallQual, GarageCars, GrLivArea, TotRmsAbv...
# 24                 {OverallQual, FullBath, GrLivArea}
# 25     {OverallQual, GarageArea, 1stFlrSF, GrLivArea}
# 26             {OverallQual, GrLivArea, TotRmsAbvGrd}
# 27  {OverallQual, GarageCars, 1stFlrSF, GarageArea...
# 28  {OverallQual, FullBath, TotalBsmtSF, GarageAre...
# 29       {OverallQual, FullBath, 1stFlrSF, GrLivArea}
#
#                                                group2    pvalue  \
# 0      {TotRmsAbvGrd, FullBath, 1stFlrSF, GarageArea}  0.000157
# 1    {GarageCars, FullBath, GarageArea, TotRmsAbvGrd}  0.000212
# 2   {GarageCars, 1stFlrSF, FullBath, GarageArea, T...  0.000460
# 3                {FullBath, GarageArea, TotRmsAbvGrd}  0.000460
# 4   {1stFlrSF, FullBath, TotalBsmtSF, GarageArea, ...  0.001077
# 5      {GarageCars, FullBath, 1stFlrSF, TotRmsAbvGrd}  0.001152
# 6                  {FullBath, 1stFlrSF, TotRmsAbvGrd}  0.001414
# 7   {GarageCars, FullBath, TotalBsmtSF, GarageArea...  0.002396
# 8                {GarageArea, 1stFlrSF, TotRmsAbvGrd}  0.002396
# 9   {TotRmsAbvGrd, FullBath, GarageArea, TotalBsmtSF}  0.002497
# 10   {GarageCars, GarageArea, 1stFlrSF, TotRmsAbvGrd}  0.002497
# 11                   {FullBath, 1stFlrSF, GarageArea}  0.003093
# 12               {GarageCars, FullBath, TotRmsAbvGrd}  0.003093
# 13       {GarageCars, FullBath, 1stFlrSF, GarageArea}  0.003197
# 14  {GarageCars, 1stFlrSF, FullBath, TotalBsmtSF, ...  0.005968
# 15                           {FullBath, TotRmsAbvGrd}  0.005968
# 16             {GarageCars, GarageArea, TotRmsAbvGrd}  0.006435
# 17    {TotRmsAbvGrd, FullBath, 1stFlrSF, TotalBsmtSF}  0.006502
# 18                 {GarageCars, FullBath, GarageArea}  0.008123
# 19                         {GarageArea, TotRmsAbvGrd}  0.010025
# 20  {GarageCars, 1stFlrSF, FullBath, TotalBsmtSF, ...  0.010198
# 21  {TotRmsAbvGrd, GarageArea, 1stFlrSF, TotalBsmtSF}  0.012611
# 22                             {FullBath, GarageArea}  0.012858
# 23      {FullBath, 1stFlrSF, GarageArea, TotalBsmtSF}  0.015564
# 24  {GarageCars, 1stFlrSF, TotalBsmtSF, GarageArea...  0.015807
# 25  {GarageCars, TotRmsAbvGrd, FullBath, TotalBsmtSF}  0.019110
# 26  {GarageCars, 1stFlrSF, FullBath, TotalBsmtSF, ...  0.019517
# 27              {TotRmsAbvGrd, FullBath, TotalBsmtSF}  0.023968
# 28               {GarageCars, 1stFlrSF, TotRmsAbvGrd}  0.023968
# 29  {GarageCars, TotRmsAbvGrd, GarageArea, TotalBs...  0.028366
#
#     adjusted pvalue
# 0          0.018517
# 1          0.024729
# 2          0.052368
# 3          0.052368
# 4          0.116514
# 5          0.123141
# 6          0.147735
# 7          0.235628
# 8          0.235628
# 9          0.240430
# 10         0.240430
# 11         0.284383
# 12         0.284383
# 13         0.287828
# 14         0.466607
# 15         0.466607
# 16         0.485704
# 17         0.485901
# 18         0.561246
# 19         0.634885
# 20         0.637515
# 21         0.711699
# 22         0.715008
# 23         0.778190
# 24         0.779892
# 25         0.836953
# 26         0.840079
# 27         0.892674
# 28         0.892674
# 29         0.924965
